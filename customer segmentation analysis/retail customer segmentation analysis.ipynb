# %% [markdown]
# <div class='alert alert-success'>
#     <h1>Customer Segmentation Analysis Project</h1>
# </div>

# %% [markdown]
# <div class='alert alert-info'>
#
# <h2>CUSTOMER SEGMENTATION ANALYSIS IN RETAIL</h2>
#
# <h3><b>CUSTOMER SEGMENTATION ANALYSIS of Malcom Retail Shop</b></h3>
#
# <h3>1. BACKGROUND</h3>
# <p>To trace the complete history of commerce back to its inception, we must travel to a time when wooly mammoths still walked the Earth. People exchanged cows and sheep in trade as far back as 9000 BC. The first retail stores take up the mantle a bit further down the line. By 800 BC in ancient Greece, people had developed markets with merchants selling their wares in the Agora in the city center. <em>Flash forward a couple thousand years and we have our modern mammoths: retail giants like Walmart, Costco, and Target.</em></p>
#
# <h4>What is Retail?</h4>
# <p>First things first. What do we mean when we say retail?</p>
#
# <b>At its simplest definition, retail is the sale of different goods and services to customers with the intention to make a profit. Retail includes selling through different channels, so items purchased in store and those purchased online both apply.</b>
#
# Retailing has evolved and throughout its evolution, there has been the collection and storage of large volumes of data which has been used to improve sales and profit.
#
# <h3>2. Business Problem</h3>
# <h4> Retailing and Big Data</h4>
#
# <p>Retailing is almost by definition a big data industry. At the macro level, thousands of stores sell hundreds of thousands of SKUs to millions of customers through billions of transactions. Walmart, for example, operates more than 11,000 stores in more than 25 countries, serves more than 35 million customers on a daily basis, and sells around 140,000 items in most of its supercenters. At a micro level, individual consumers have become walking data generators that leave a data trail each time they make a purchase with their credit card, use a loyalty card, send a text message, or search the web (Muller, 2014).</p>
#
# Since huge volumes of data is collected in retail businesses, there have been an improved struggle among businesses about how to access the huge volumes of data and leverage the information and insights they can acquire to improve their businesses by optimizing their decisions and improving sales and customer satisfaction.
#
# A 2019 study found that 84% of B2B marketers expect to see value from their machine learning investments within a year and another one found that 85% of marketers using artificial intelligence believe it will drive double-digit revenue growth within two years. It is becoming clearer every day that every aspect of marketing can and will be improved with machine learning.
# <p>Machine learning is a method of data analysis that automates analytical model building. It is a branch of artificial intelligence based on the idea that systems can learn from data, identify patterns and make decisions with minimal human intervention.</p>
#
# <h3>3. Problem Statement</h3>
#
# Malcom Retail Shop is seeking to increase sales and improve customer satisfaction by use of Data Analysis and Machine Learning. The Retail Shop has collected large volumes of transaction data and want to find a way to gain insights pertaining to their customers in order to target the right customers for targeted marketing, which is an effective way of utilizing resources and optimizing operations and hence boosting sales whiles increasing customer satisfaction. In order to use targeted marketing, they need to know and understand their customers by purchasing behavior and patterns, preferences, geography, etc.
#
# <p>According to Walker, 2020 is the year where businesses need to shift their mindsets from "customer-focused" to "customer-committed." For years, aggressive customer acquisition strategies have dominated the marketing space. But as cost containment becomes a priority for businesses looking to thrive in the modern digitally-transformed marketplace, keeping existing customers happy and loyal is now a primary concern.</p>
#
# Creating effective marketing campaigns, R&D strategies, and sales processes in retail require a clear and consistent understanding of customers. We are exploring the concept of <b><em>Customer Segmentation</em></b> and which will be used to analyse the customer data selected for the purposes of the project.
#
# <h3>Customer segmentation and discovery</h3>
# "Customer segmentation refers to a method of dividing customers into groups or clusters on the basis of common characteristics". Data Camp 2021
#
# <b>Unsupervised algorithms in Machine Learning</b>, such as <b>K-means clustering or DBSCAN</b> <em>can identify patterns in your data and reveal how your customers are clustered by factors such as age, income, address, interests etc...</em> The more information you obtain about your customers, the more accurate the clusters will be, which is a general rule in machine learning. You can then label those clusters and customize your approach to their needs and expectations.
#
# There are different types of customer segmentation and this includes but not limited to:
# <li><b>Demographics</b>, which entails the information on gender, age, familial status, income.</li>
# <li><b>Geographics</b>, includes localised information on city,town, country</li>
# <li><b>Pyschographics</b>, includes information on social class, lifestyle</li>
# <li><b>Behavioural</b>, entails the spending, consumption habits for products and services.</li>
#
# The advantages of using Customer Segmentation are as follows:
# - It helps to identify loyal customers
# - It can facilitate the company's ability to upsell and crossell.
# - It can help company's to be more competitive as it provides strategic information about customer.
# - It  helps to identify new products that customers can be intrested in.
#
#
# <h4>PROJECT DATA SET</h4>
#
# The data set provides details of customers which includes product description, invoice number, quantity, invoice date, unit price, customer ID, country and sales. Hence we are able to analyse the customer data using segmentation based on their geographic characteristics in terms of location and behavioural characteristics based on spending and consumpuption patterns of the customers.
# However, it is important to note the limitations and constraints of the data set in that there is no demographic data or pyschographic data.
#  2010-12-01 08:26:00
# last      2011-12-09 12:50:00
#
# <h3>4. Methodology</h3>
#
# <p>To resolve the problem as stated, the data set will be analysed using the methods noted below to
# identify customer segments using K-means and RFM (Recency,Frequency,Monetary) with Length of Relationship metric.</p>
#
# <h3>Methods</h3>
# <h6>1. Data Acquisition</h6><p>Malcom Retail data was used for this study. The transaction data used ranges from 1st December 2010 to 9th December 2011. Each customer is uniquely identified with an ID that allows for consistent analysis, but the IDs are generated internally, which means that the customer has no knowledge of their ID. There is a way to keep track of a particular customer’s purchases. The data consist of customer id, quantity purchased, Invoice Number, Invoice Date, Stock Code, Description of purchased items, Unit Price and Country where customer reside. The invoice date helps us to know the time of transaction, total quantity bought, the unit price of the product and the customer ID. The time of transaction, total quantity bought, the unit price of the product and associated customer ID are relevant for this particular analysis.</p>
#
# <h6>2. Data Cleansing and Exploratory Data Analysis</h6><p>At this stage, data quality was ensured by cleaning and removing missing or wrong values such as negative values of sales and unit price percieved to be returned goods or data entry error.</p>
#
# <h6>3. Feature engineering</h6><p>At this stage, the cleaned data was grouped into customerid and specific calculations were done on selected columns to derive new features with which the analysis will be done, customers will be scored and loyalty labels assigned, and Kmeans model will be built.</p>
# <h6>Recency-Frequency Monetary (RFM) Method Used</h6>
# RFM model was used for this study. This because each of the components are defined in a way that makes them easy to collect, it is a relatively menial task for a retailer to visualize the results, which makes interpretation easy as well.
#
# > <b>Recency (R)</b> as days since last purchase: How many days ago was their last purchase? Deduct most recent purchase date from today to calculate the recency value. 1 day ago? 14 days ago? 500 days ago?
#
# > <b>Frequency (F)</b> as total number of transactions: How many times has the customer purchased from our store? For example, if someone placed 10 orders over a period of time, their frequency is 10.
#
# > <b>Monetary (M)</b> as total money spent: How many $$ (or whatever is your currency of calculation) has this customer spent? Again limit to last two years – or take all time. Simply total up the money from all transactions to get the M value.
#
# > One more metric added was the <b>Length of Relationship(LOR)</b> as how long the customer has traded with the shop. Calculated by taking the days difference of each customer's last day of purchase and first day of purchase.
#
# <h6>4. Customer Score Calculation and Loyalty Labelling</h6><p>Customer score were calculated using the engineered features and Loyalty levels were assigned.</p>
# <h6>5. KMeans Modelling</h6><p>The KMeans model was built using optimal clusters</p>
# <h6>6. In depth analysis of the Loyalty Levels and Clusters</h6><p>At this stage, the Customers Loyalty Levels and Customer Groups were described in order to gain insights into the customer groups Malcom retail had, their characteristics, buying patterns, etc. and how to target each customer group.</p>
#
#
# </div>

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sidetable

# %% [markdown]
# ### Import data

# %%
data = pd.read_csv('data.csv', encoding='latin1')

# %% [markdown]
# ### Data Inspection

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.columns = data.columns.str.lower()

# %%
data.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.describe()
# Out:
#             quantity      unitprice     customerid
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# > Columns quantity and unitprice have negative values which are unnatural for quantity and unit price of a product.
#
#
# ### further investigation

# %% [markdown]
# ### checking the frequency of quantity to inspect rows with negative values

# %%
data.stb.freq(['quantity'])
# Out:
#      quantity   count    percent  cumulative_count  cumulative_percent
# 0           1  148227  27.352747            148227           27.352747
# 1           2   81829  15.100137            230056           42.452884
# 2          12   61063  11.268128            291119           53.721012
# 3           6   40868   7.541488            331987           61.262500
# 4           4   38484   7.101561            370471           68.364061
# ..        ...     ...        ...               ...                 ...
# 717     -5368       1   0.000185            541905           99.999262
# 718     -9058       1   0.000185            541906           99.999446
# 719     -9360       1   0.000185            541907           99.999631
# 720    -74215       1   0.000185            541908           99.999815
# 721    -80995       1   0.000185            541909          100.000000
#
# [722 rows x 5 columns]

# %% [markdown]
# > 10, 624 quantity rows had negative values

# %%
data.loc[data.quantity < 0, ].shape[0]
# Out:
# 10624

# %% [markdown]
# > dropping the negative values

# %%
data = data[data.quantity > 0]
data.shape
# Out:
# (531285, 8)

# %%
data.stb.freq(['quantity'])
# Out:
#      quantity   count    percent  cumulative_count  cumulative_percent
# 0           1  148227  27.899715            148227           27.899715
# 1           2   81829  15.402091            230056           43.301806
# 2          12   61063  11.493455            291119           54.795261
# 3           6   40868   7.692293            331987           62.487554
# 4           4   38484   7.243570            370471           69.731124
# ..        ...     ...        ...               ...                 ...
# 388       133       1   0.000188            531281           99.999247
# 389       122       1   0.000188            531282           99.999435
# 390       107       1   0.000188            531283           99.999624
# 391       106       1   0.000188            531284           99.999812
# 392        77       1   0.000188            531285          100.000000
#
# [393 rows x 5 columns]

# %%
data.quantity.describe()
# Out:
# count    531285.000000
# mean         10.655262
# std         156.830323
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: quantity, dtype: float64

# %%
data.quantity.plot(kind='box')

# %%
data.describe()
# Out:
#             quantity      unitprice     customerid
# count  531285.000000  531285.000000  397924.000000
# mean       10.655262       3.857296   15294.315171
# std       156.830323      41.810047    1713.169877
# min         1.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     80995.000000   13541.330000   18287.000000

# %% [markdown]
# ### Create new column sales, as a product of unitprice and quantity

# %%
data['sales'] = data.unitprice*data.quantity

# %%
data.describe()
# Out:
#             quantity      unitprice     customerid         sales
# count  531285.000000  531285.000000  397924.000000  531285.00000
# mean       10.655262       3.857296   15294.315171      20.03550
# std       156.830323      41.810047    1713.169877     270.91237
# min         1.000000  -11062.060000   12346.000000  -11062.06000
# 25%         1.000000       1.250000   13969.000000       3.75000
# 50%         3.000000       2.080000   15159.000000       9.90000
# 75%        10.000000       4.130000   16795.000000      17.70000
# max     80995.000000   13541.330000   18287.000000  168469.60000

# %%
data.stb.missing()
# Out:
#              missing   total    percent
# customerid    133361  531285  25.101593
# description      592  531285   0.111428
# invoiceno          0  531285   0.000000
# stockcode          0  531285   0.000000
# quantity           0  531285   0.000000
# invoicedate        0  531285   0.000000
# unitprice          0  531285   0.000000
# country            0  531285   0.000000
# sales              0  531285   0.000000

# %%
data[data['unitprice'] == 0]
# Out:
#        invoiceno stockcode                   description  quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 535334    581211     22142                         check        14
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
#
#             invoicedate  unitprice  customerid         country  sales
# 622     12/1/2010 11:52        0.0         NaN  United Kingdom    0.0
# ...

# %%
data[data['unitprice'] == 0].shape[0]
# Out:
# 1179

# %% [markdown]
# #### Drop all rows where unitprice is 0 and description is not available

# %%
#drop all rows with missing description

data.dropna(axis=0, inplace = True, subset=['description'])

# %%
#drop all rows with unitprice of 0

data.dropna(axis=0, inplace = True, subset=['unitprice'])

# %%
# drop all rows with missing customerid since we can't associate clusters to missing customers

data.dropna(axis=0, inplace=True, subset=['customerid'])

# %%
#drop all rows where unitprice was 0

data.drop(data[data['unitprice'] == 0].index, inplace = True)

# %%
data.stb.missing()
# Out:
#              missing   total  percent
# invoiceno          0  397884      0.0
# stockcode          0  397884      0.0
# description        0  397884      0.0
# quantity           0  397884      0.0
# invoicedate        0  397884      0.0
# unitprice          0  397884      0.0
# customerid         0  397884      0.0
# country            0  397884      0.0
# sales              0  397884      0.0

# %%
data.head(10)
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       invoicedate  unitprice  customerid         country  sales
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# ...

# %%
data.describe()
# Out:
#             quantity      unitprice     customerid          sales
# count  397884.000000  397884.000000  397884.000000  397884.000000
# mean       12.988238       3.116488   15294.423453      22.397000
# std       179.331775      22.097877    1713.141560     309.071041
# min         1.000000       0.001000   12346.000000       0.001000
# 25%         2.000000       1.250000   13969.000000       4.680000
# 50%         6.000000       1.950000   15159.000000      11.800000
# 75%        12.000000       3.750000   16795.000000      19.800000
# max     80995.000000    8142.750000   18287.000000  168469.600000

# %%
data.country.value_counts()
# Out:
# United Kingdom          354321
# Germany                   9040
# France                    8341
# EIRE                      7236
# Spain                     2484
# Netherlands               2359
# Belgium                   2031
# Switzerland               1841
# Portugal                  1462
# Australia                 1182
# Norway                    1071
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     248
# Unspecified                244
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# ...

# %%
data.shape
# Out:
# (397884, 9)

# %%
# save cleaned data

data.to_csv('cleaned_data.csv', encoding='utf-8')

# %%
clean_data = pd.read_csv('cleaned_data.csv')
clean_data.drop('Unnamed: 0', axis=1, inplace=True)
clean_data.head()
# Out:
#    invoiceno stockcode                          description  quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       invoicedate  unitprice  customerid         country  sales
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
clean_data.shape
# Out:
# (397884, 9)

# %%
plt.figure(figsize=(6, 14))

data.country.value_counts().nlargest(10).plot(kind='bar')

# %%
data.groupby(['description', 'country'])['invoiceno'].count()
# Out:
# description                       country
#  4 PURPLE FLOCK DINNER CANDLES    EIRE                1
#                                   United Kingdom     38
#  50'S CHRISTMAS GIFT BAG LARGE    EIRE                1
#                                   France              1
#                                   Germany             5
#                                                    ...
# ZINC WILLIE WINKIE  CANDLE STICK  United Kingdom    173
# ZINC WIRE KITCHEN ORGANISER       Portugal            1
#                                   United Kingdom     11
# ZINC WIRE SWEETHEART LETTER TRAY  EIRE                1
#                                   United Kingdom     19
# Name: invoiceno, Length: 19321, dtype: int64

# %% [markdown]
# ### Load Cleaned Data

# %%
data = pd.read_csv('cleaned_data.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data.invoicedate = pd.to_datetime(data.invoicedate)
data.head(3)
# Out:
#    invoiceno stockcode                         description  quantity  \
# 0     536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                 WHITE METAL LANTERN         6
# 2     536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           invoicedate  unitprice  customerid         country  sales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00

# %%
data.invoicedate.describe()
# Out:
# count                  397884
# unique                  17282
# top       2011-11-14 15:27:00
# freq                      542
# first     2010-12-01 08:26:00
# last      2011-12-09 12:50:00
# Name: invoicedate, dtype: object

# %% [markdown]
# ### Inspection

# %%
data.shape
# Out:
# (397884, 9)

# %%
data.stb.missing()
# Out:
#              missing   total  percent
# invoiceno          0  397884      0.0
# stockcode          0  397884      0.0
# description        0  397884      0.0
# quantity           0  397884      0.0
# invoicedate        0  397884      0.0
# unitprice          0  397884      0.0
# customerid         0  397884      0.0
# country            0  397884      0.0
# sales              0  397884      0.0

# %%
data.description.describe()
# Out:
# count                                 397884
# unique                                  3877
# top       WHITE HANGING HEART T-LIGHT HOLDER
# freq                                    2028
# Name: description, dtype: object

# %% [markdown]
# ### Exploratory Data Analysis

# %%
data.groupby(['customerid', 'description'])[['sales']].sum().nlargest(10, 'sales')
# Out:
#                                                    sales
# customerid description
# 16446.0    PAPER CRAFT , LITTLE BIRDIE         168469.60
# 12346.0    MEDIUM CERAMIC TOP STORAGE JAR       77183.60
# 15098.0    PICNIC BASKET WICKER 60 PIECES       39619.50
# 18102.0    VINTAGE UNION JACK MEMOBOARD         16592.08
# 16210.0    BLACK RECORD COVER FRAME             16027.92
# 18102.0    WOOD BLACK BOARD ANT WHITE FINISH    15351.00
#            CREAM HEART CARD HOLDER              14089.90
# 15061.0    REGENCY CAKESTAND 3 TIER             14081.70
# 17450.0    HEART OF WICKER LARGE                13459.64
#            WHITE HANGING HEART T-LIGHT HOLDER   13253.84

# %%
data.groupby(['customerid', 'description'])[['sales']].mean().nlargest(10, 'sales')
# Out:
#                                                    sales
# customerid description
# 16446.0    PAPER CRAFT , LITTLE BIRDIE         168469.60
# 12346.0    MEDIUM CERAMIC TOP STORAGE JAR       77183.60
# 15098.0    PICNIC BASKET WICKER 60 PIECES       19809.75
# 16029.0    POSTAGE                               8142.75
# 15749.0    FAIRY CAKE FLANNEL ASSORTED COLOUR    6539.40
#            WHITE HANGING HEART T-LIGHT HOLDER    4776.75
#            DOORMAT FAIRY CAKE                    4388.50
# 12536.0    Manual                                4161.06
# 15195.0    METAL SIGN TAKE IT OR LEAVE IT        3861.00
# 12755.0    ROUND SNACK BOXES SET OF 4 FRUITS     3794.40

# %%
data.description.nunique()
# Out:
# 3877

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Snapshot date for calculating Recency

# %%
# create date(next day when data was collected) from which to subtract and find days since last purchase
from datetime import timedelta

# create date
last_date = data.invoicedate.max() + timedelta(days=1)

# %% [markdown]
# ### Grouping data by customerid

# %%
data['invoicedate2'] = data.invoicedate
data.head(10)
# Out:
#    invoiceno stockcode                          description  quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           invoicedate  unitprice  customerid         country  sales  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# ...

# %% [markdown]
# ### Engineer required features: Recency, Frequency, Moneytary and Length of Relationship

# %%
customers = data.groupby(['customerid']).agg({
    'invoicedate':lambda x: (last_date - x.max()).days,
    'invoiceno': 'count',
    'sales': 'sum',
    'invoicedate2':lambda x: (x.max() - x.min()).days
})

customers.head()
# Out:
#             invoicedate  invoiceno     sales  invoicedate2
# customerid
# 12346.0             326          1  77183.60             0
# 12347.0               2        182   4310.00           365
# 12348.0              75         31   1797.24           282
# 12349.0              19         73   1757.55             0
# 12350.0             310         17    334.40             0

# %% [markdown]
# ### rename columns

# %%
customers.rename(columns={'invoicedate':'recency',
                         'invoiceno': 'frequency',
                         'sales': 'monetary',
                         'invoicedate2':'length_of_relationship'}, inplace=True)
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship
# customerid
# 12346.0         326          1  77183.60                       0
# 12347.0           2        182   4310.00                     365
# 12348.0          75         31   1797.24                     282
# 12349.0          19         73   1757.55                       0
# 12350.0         310         17    334.40                       0

# %% [markdown]
# ### Inspection

# %%
data[data.customerid == 12346.0]
# Out:
#        invoiceno stockcode                     description  quantity  \
# 37120     541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#               invoicedate  unitprice  customerid         country    sales  \
# 37120 2011-01-18 10:01:00       1.04     12346.0  United Kingdom  77183.6
#
#              invoicedate2
# 37120 2011-01-18 10:01:00

# %%
data[data.customerid == 12348.0]
# Out:
#         invoiceno stockcode                         description  quantity  \
# 23008      539318     84992      72 SWEETHEART FAIRY CAKE CASES        72
# 23009      539318     22951     60 CAKE CASES DOLLY GIRL DESIGN        72
# 23010      539318     84991         60 TEATIME FAIRY CAKE CASES        24
# 23011      539318     84991         60 TEATIME FAIRY CAKE CASES       120
# 23012      539318     21213         PACK OF 72 SKULL CAKE CASES        24
# 23013      539318     21213         PACK OF 72 SKULL CAKE CASES       120
# 23014      539318     22616          PACK OF 12 LONDON TISSUES         72
# 23015      539318     21981        PACK OF 12 WOODLAND TISSUES        144
# 23016      539318     21982            PACK OF 12 SUKI TISSUES        144
# 23017      539318     21725                  SWEETIES  STICKERS        48
# 23018      539318     21211      SET OF 72 SKULL PAPER  DOILIES        72
# 23019      539318     84988  SET OF 72 PINK HEART PAPER DOILIES        48
# ...

# %%
customers.shape
# Out:
# (4338, 4)

# %%
customers.describe()
# Out:
#            recency    frequency       monetary  length_of_relationship
# count  4338.000000  4338.000000    4338.000000             4338.000000
# mean     92.536422    91.720609    2054.266460              130.448594
# std     100.014169   228.785094    8989.230441              132.039554
# min       1.000000     1.000000       3.750000                0.000000
# 25%      18.000000    17.000000     307.415000                0.000000
# 50%      51.000000    41.000000     674.485000               92.500000
# 75%     142.000000   100.000000    1661.740000              251.750000
# max     374.000000  7847.000000  280206.020000              373.000000

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4338 entries, 12346.0 to 18287.0
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   recency                 4338 non-null   int64
#  1   frequency               4338 non-null   int64
#  2   monetary                4338 non-null   float64
#  3   length_of_relationship  4338 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 169.5 KB

# %% [markdown]
# ### Distribution Plot of Recency, Frequency, Monetary and Length of Relationship

# %%
customers.hist(figsize=(14, 10), bins=10, color='red')
plt.show()

# %% [markdown]
# ### Calculate Recency, Frequency, Monetary and Length of relationship(lor) Score groups
#
# > **lor groups were formed by dividing the column into 4 quartiles and assigning labels of 1-4, the higher the number, the longer the length of relationship**

# %%
# create labels for recency, monetary, frequency and length of relationship

r = range(4, 0, -1)
m = range(1, 5)
f = range(1, 5)
l = [1, 2, 3, 4]

# assign labels to 4 equal percenttile groups

r_group = pd.qcut(customers.recency, q=4, labels=r)
m_group = pd.qcut(customers.monetary, q=4, labels=m)
f_group = pd.qcut(customers.frequency, q=4, labels=f)
lor_group = pd.qcut(customers.length_of_relationship, q=5, labels=l, duplicates='drop')

# add new group columns 
customers['r_score'] = r_group
customers['m_score'] =  m_group
customers['f_score'] = f_group
customers['lor_score'] = lor_group

customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship r_score  \
# customerid
# 12346.0         326          1  77183.60                       0       1
# 12347.0           2        182   4310.00                     365       4
# 12348.0          75         31   1797.24                     282       2
# 12349.0          19         73   1757.55                       0       3
# 12350.0         310         17    334.40                       0       1
#
#            m_score f_score lor_score
# customerid
# 12346.0          4       1         1
# 12347.0          4       4         4
# 12348.0          4       2         4
# 12349.0          4       3         1
# 12350.0          2       1         1

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4338 entries, 12346.0 to 18287.0
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   recency                 4338 non-null   int64
#  1   frequency               4338 non-null   int64
#  2   monetary                4338 non-null   float64
#  3   length_of_relationship  4338 non-null   int64
#  4   r_score                 4338 non-null   category
#  5   m_score                 4338 non-null   category
#  6   f_score                 4338 non-null   category
#  7   lor_score               4338 non-null   category
# dtypes: category(4), float64(1), int64(3)
# memory usage: 187.0 KB

# %%
scores = ['r_score', 'm_score', 'f_score', 'lor_score']

for score in scores:
    customers[score] = customers[score].astype(int)
    
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4338 entries, 12346.0 to 18287.0
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   recency                 4338 non-null   int64
#  1   frequency               4338 non-null   int64
#  2   monetary                4338 non-null   float64
#  3   length_of_relationship  4338 non-null   int64
#  4   r_score                 4338 non-null   int64
#  5   m_score                 4338 non-null   int64
#  6   f_score                 4338 non-null   int64
#  7   lor_score               4338 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 305.0 KB

# %% [markdown]
# ### Add all Score Values

# %%
def add_rmvf(x):
    return str(x['r_score']) + str(x['m_score']) + str(x['f_score']) + str(x['lor_score'])

# %%
customers['customer_score'] = customers.apply(add_rmvf, axis=1)

# %%
customers.customer_score = customers.customer_score.astype(int)
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score
# customerid
# 12346.0           4        1          1            1411
# 12347.0           4        4          4            4444
# 12348.0           4        2          4            2424
# 12349.0           4        3          1            3431
# 12350.0           2        1          1            1211

# %% [markdown]
# ### Summing the values into Customer Score

# %%
customers['customer_score'] = customers[['r_score', 'f_score', 'm_score', 'lor_score']].sum(axis=1)
customers['customer_score'].head()
# Out:
# customerid
# 12346.0     7
# 12347.0    16
# 12348.0    12
# 12349.0    11
# 12350.0     5
# Name: customer_score, dtype: int64

# %% [markdown]
# ### Customer Score Inspection

# %%
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score
# customerid
# 12346.0           4        1          1               7
# 12347.0           4        4          4              16
# 12348.0           4        2          4              12
# 12349.0           4        3          1              11
# 12350.0           2        1          1               5

# %%
customers.customer_score.describe()
# Out:
# count    4338.000000
# mean        9.701706
# std         3.743567
# min         4.000000
# 25%         6.000000
# 50%        10.000000
# 75%        13.000000
# max        16.000000
# Name: customer_score, dtype: float64

# %%
sns.distplot(customers.customer_score)

# %%
customers.customer_score.value_counts().sort_values(ascending=False)
# Out:
# 6     415
# 7     399
# 4     356
# 5     349
# 11    339
# 10    333
# 16    326
# 8     321
# 9     317
# 13    309
# 12    298
# 14    295
# 15    281
# Name: customer_score, dtype: int64

# %%
customers.stb.freq(['customer_score'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_0c77b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >customer_score</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c77b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0c77b_row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_0c77b_row0_col1" class="data row0 col1" >415</td>
#                         <td id="T_0c77b_row0_col2" class="data row0 col2" >9.57%</td>
#                         <td id="T_0c77b_row0_col3" class="data row0 col3" >415</td>
#                         <td id="T_0c77b_row0_col4" class="data row0 col4" >9.57%</td>
# ...

# %% [markdown]
# ### Assign Loyalty Level to each customer using the Customer Score

# %%
Loyalty_Levels = ['Bronze', 'Silver', 'Gold', 'Platinum']
loyalty_levels = pd.qcut(customers.customer_score, q = 4, labels = Loyalty_Levels)
customers['loyalty_level'] = loyalty_levels

# %%
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score loyalty_level
# customerid
# 12346.0           4        1          1               7        Silver
# 12347.0           4        4          4              16      Platinum
# 12348.0           4        2          4              12          Gold
# 12349.0           4        3          1              11          Gold
# 12350.0           2        1          1               5        Bronze

# %%
customers.loyalty_level.value_counts()
# Out:
# Silver      1370
# Bronze      1120
# Gold         946
# Platinum     902
# Name: loyalty_level, dtype: int64

# %%
customers.stb.freq(['loyalty_level'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_c835b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >loyalty_level</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c835b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c835b_row0_col0" class="data row0 col0" >Silver</td>
#                         <td id="T_c835b_row0_col1" class="data row0 col1" >1,370</td>
#                         <td id="T_c835b_row0_col2" class="data row0 col2" >31.58%</td>
#                         <td id="T_c835b_row0_col3" class="data row0 col3" >1,370</td>
# ...

# %%
plt.pie(customers.loyalty_level.value_counts(), labels=customers.loyalty_level.value_counts().index, autopct='%1.1f%%')
plt.title('Loyalty Levels', weight='bold')
plt.show()

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.countplot(customers.loyalty_level, palette=colors)
plt.title('Loyalty Levels', fontsize=13, weight='bold')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('loyalty level', fontsize=11, weight='bold')
plt.ylabel('count', fontsize=11, weight='bold')
plt.show()

# %% [markdown]
# ###  Description of Loyalty Levels

# %% [markdown]
# #### Description of Platinum Loyalty

# %%
filta = customers.loyalty_level == 'Platinum'

platinum = customers[filta]
platinum.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12347.0           2        182   4310.00                     365        4
# 12356.0          23         59   2811.43                     302        3
# 12362.0           3        266   5226.23                     292        4
# 12370.0          51        167   3545.69                     309        3
# 12388.0          16        100   2780.66                     311        4
#
#             m_score  f_score  lor_score  customer_score loyalty_level
# customerid
# 12347.0           4        4          4              16      Platinum
# 12356.0           4        3          4              14      Platinum
# 12362.0           4        4          4              16      Platinum
# 12370.0           4        4          4              15      Platinum
# 12388.0           4        3          4              15      Platinum

# %%
platinum.shape
# Out:
# (902, 10)

# %%
platinum.describe().style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
# #T_6d5a1_row0_col0,#T_6d5a1_row0_col3,#T_6d5a1_row0_col4,#T_6d5a1_row0_col5,#T_6d5a1_row0_col6,#T_6d5a1_row0_col7,#T_6d5a1_row0_col8,#T_6d5a1_row7_col1,#T_6d5a1_row7_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_6d5a1_row0_col1{
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }#T_6d5a1_row0_col2,#T_6d5a1_row1_col4,#T_6d5a1_row1_col5,#T_6d5a1_row1_col6,#T_6d5a1_row1_col7,#T_6d5a1_row2_col4,#T_6d5a1_row2_col5,#T_6d5a1_row2_col6,#T_6d5a1_row2_col7,#T_6d5a1_row2_col8,#T_6d5a1_row3_col0,#T_6d5a1_row3_col1,#T_6d5a1_row3_col2,#T_6d5a1_row3_col3,#T_6d5a1_row3_col4,#T_6d5a1_row3_col5,#T_6d5a1_row3_col6,#T_6d5a1_row3_col7,#T_6d5a1_row4_col0,#T_6d5a1_row4_col4,#T_6d5a1_row4_col7,#T_6d5a1_row5_col4,#T_6d5a1_row5_col7,#T_6d5a1_row6_col4,#T_6d5a1_row6_col7,#T_6d5a1_row7_col4,#T_6d5a1_row7_col7{
#             background-color:  #f7fcf5;
#             color:  #000000;
# ...

# %% [markdown]
# #### Description of Gold Loyalty

# %%
filta = customers.loyalty_level == 'Gold'

gold = customers[filta]
gold.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12352.0          36         85   2506.04                     260        3
# 12357.0          33        131   6207.67                       0        3
# 12358.0           2         19   1168.06                     149        4
#
#             m_score  f_score  lor_score  customer_score loyalty_level
# customerid
# 12348.0           4        2          4              12          Gold
# 12349.0           4        3          1              11          Gold
# 12352.0           4        3          3              13          Gold
# 12357.0           4        4          1              12          Gold
# 12358.0           3        2          2              11          Gold

# %%
gold.shape
# Out:
# (946, 10)

# %%
gold.describe().style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
# #T_ee1e5_row0_col0,#T_ee1e5_row0_col1,#T_ee1e5_row0_col3,#T_ee1e5_row0_col4,#T_ee1e5_row0_col5,#T_ee1e5_row0_col6,#T_ee1e5_row0_col7,#T_ee1e5_row0_col8,#T_ee1e5_row7_col2{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_ee1e5_row0_col2,#T_ee1e5_row5_col2{
#             background-color:  #fff5ea;
#             color:  #000000;
#         }#T_ee1e5_row1_col0{
#             background-color:  #fff0e1;
#             color:  #000000;
#         }#T_ee1e5_row1_col1{
#             background-color:  #feead6;
#             color:  #000000;
#         }#T_ee1e5_row1_col2,#T_ee1e5_row3_col8,#T_ee1e5_row4_col8,#T_ee1e5_row6_col2{
#             background-color:  #fff4e9;
#             color:  #000000;
#         }#T_ee1e5_row1_col3{
#             background-color:  #fdd8b2;
#             color:  #000000;
# ...

# %% [markdown]
# #### Description of Silver Loyalty

# %%
filta = customers.loyalty_level == 'Silver'

silver = customers[filta]
silver.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12354.0         232         58   1079.40                       0        1
# 12363.0         110         23    552.00                     132        2
# 12367.0           4         11    168.90                       0        4
# 12374.0          25         33    742.93                       0        3
#
#             m_score  f_score  lor_score  customer_score loyalty_level
# customerid
# 12346.0           4        1          1               7        Silver
# 12354.0           3        3          1               8        Silver
# 12363.0           2        2          2               8        Silver
# 12367.0           1        1          1               7        Silver
# 12374.0           3        2          1               9        Silver

# %%
silver.shape
# Out:
# (1370, 10)

# %%
silver.describe().style.background_gradient(cmap='Greys')
# Out:
# <style  type="text/css" >
# #T_455ef_row0_col0,#T_455ef_row0_col1,#T_455ef_row0_col3,#T_455ef_row0_col4,#T_455ef_row0_col5,#T_455ef_row0_col6,#T_455ef_row0_col7,#T_455ef_row0_col8,#T_455ef_row7_col2{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_455ef_row0_col2,#T_455ef_row2_col1,#T_455ef_row4_col0,#T_455ef_row5_col1{
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }#T_455ef_row1_col0,#T_455ef_row2_col3{
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }#T_455ef_row1_col1,#T_455ef_row5_col3{
#             background-color:  #fcfcfc;
#             color:  #000000;
#         }#T_455ef_row1_col2,#T_455ef_row4_col1,#T_455ef_row6_col2{
#             background-color:  #fefefe;
#             color:  #000000;
#         }#T_455ef_row1_col3{
#             background-color:  #f9f9f9;
#             color:  #000000;
# ...

# %% [markdown]
# #### Description of Bronze Loyalty

# %%
filta = customers.loyalty_level == 'Bronze'

bronze = customers[filta]
bronze.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12350.0         310         17    334.40                       0        1
# 12353.0         204          4     89.00                       0        1
# 12355.0         214         13    459.40                       0        1
# 12361.0         287         10    189.90                       0        1
# 12365.0         291         22    641.38                       0        1
#
#             m_score  f_score  lor_score  customer_score loyalty_level
# customerid
# 12350.0           2        1          1               5        Bronze
# 12353.0           1        1          1               4        Bronze
# 12355.0           2        1          1               5        Bronze
# 12361.0           1        1          1               4        Bronze
# 12365.0           2        2          1               6        Bronze

# %%
bronze.shape
# Out:
# (1120, 10)

# %%
bronze.describe().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_4d37b_row0_col0,#T_4d37b_row0_col1,#T_4d37b_row0_col3,#T_4d37b_row0_col4,#T_4d37b_row0_col5,#T_4d37b_row0_col6,#T_4d37b_row0_col7,#T_4d37b_row0_col8,#T_4d37b_row7_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_4d37b_row0_col2{
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }#T_4d37b_row1_col0{
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }#T_4d37b_row1_col1{
#             background-color:  #fff3ed;
#             color:  #000000;
#         }#T_4d37b_row1_col2{
#             background-color:  #fed8c7;
#             color:  #000000;
#         }#T_4d37b_row1_col3,#T_4d37b_row4_col1,#T_4d37b_row6_col8,#T_4d37b_row7_col8{
#             background-color:  #fff4ef;
#             color:  #000000;
# ...

# %% [markdown]
# <div class='alert alert-danger'></div>

# %% [markdown]
# ### Feature Selection using KBest

# %%
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score loyalty_level
# customerid
# 12346.0           4        1          1               7        Silver
# 12347.0           4        4          4              16      Platinum
# 12348.0           4        2          4              12          Gold
# 12349.0           4        3          1              11          Gold
# 12350.0           2        1          1               5        Bronze

# %% [markdown]
# ### Selecting features: using recency, frequency, monetary and length of relationship as X values and Customer Score as y value

# %%
Xy = customers[['recency', 'frequency', 'monetary', 'length_of_relationship', 'customer_score']]
X = customers[['recency', 'frequency', 'monetary', 'length_of_relationship']]
y = customers['customer_score']

# %% [markdown]
# ### Exploring Relationship between values

# %%
Xy.corr().style.background_gradient(cmap='BuPu')
# Out:
# <style  type="text/css" >
# #T_c165d_row0_col0,#T_c165d_row1_col1,#T_c165d_row2_col2,#T_c165d_row3_col3,#T_c165d_row4_col4{
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }#T_c165d_row0_col1,#T_c165d_row0_col2,#T_c165d_row0_col3,#T_c165d_row0_col4,#T_c165d_row4_col0{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_c165d_row1_col0{
#             background-color:  #b6cde3;
#             color:  #000000;
#         }#T_c165d_row1_col2{
#             background-color:  #8e9ac8;
#             color:  #000000;
#         }#T_c165d_row1_col3{
#             background-color:  #8c82bc;
#             color:  #000000;
#         }#T_c165d_row1_col4{
#             background-color:  #8b65ae;
#             color:  #000000;
#         }#T_c165d_row2_col0{
#             background-color:  #a9c4de;
#             color:  #000000;
#         }#T_c165d_row2_col1{
#             background-color:  #8c8fc2;
# ...

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(Xy.corr(), annot=True, )
plt.show()

# %%
sns.pairplot(Xy)
plt.show()

# %% [markdown]
# <div class='alert alert-info'>
# <h3>Findings:</h3>
#
# > <b>Customer Score is positively correlated to length of relationship at 0.85 coeff.</b>
#
# > <b>Next in line is frequency at 0.4 coeff and monetary at 0.24 coeff.</b>
#
# > <b>Customer Score is negatively correlated to recency at -0.68 coeff.</b>
#
# > <b>Length of relationship is negatively correlated to recency at -0.51 coeff.</b>
# </div>

# %% [markdown]
# ### Features and scores

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=f_classif, k='all')
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['column_name','Score']  #naming the dataframe columns
#print(featureScores.nlargest(10,'Score'))  #print 10 best features
print(featureScores.sort_values(ascending=False, by='Score'))
# Out:
#               column_name        Score
# 3  length_of_relationship  1046.954771
# 0                 recency   422.158141
# 1               frequency   104.178345
# 2                monetary    41.862222

# %%
featureScores.sort_values(ascending=False, by='Score').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_290fe_row0_col1{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_290fe_row1_col1{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_290fe_row2_col1{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_290fe_row3_col1{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_290fe_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column_name</th>        <th class="col_heading level0 col1" >Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_290fe_level0_row0" class="row_heading level0 row0" >3</th>
#                         <td id="T_290fe_row0_col0" class="data row0 col0" >length_of_relationship</td>
#                         <td id="T_290fe_row0_col1" class="data row0 col1" >1046.954771</td>
# ...

# %% [markdown]
# > **Length of relationship and recency came out as the 2 best features using customer score as y variable**

# %% [markdown]
# ### Clustering Using the 2 best features: Recency and Length of Relationship

# %%
best2 = X.drop(['frequency', 'monetary'], axis=1)
best2.head()
# Out:
#             recency  length_of_relationship
# customerid
# 12346.0         326                       0
# 12347.0           2                     365
# 12348.0          75                     282
# 12349.0          19                       0
# 12350.0         310                       0

# %% [markdown]
# ### Calculating Scoring metrics with recency and length of relationship

# %% [markdown]
# > **The lower the recency, the higher the score. Values are within 1 - 4, low to high**
#
# > **The higher the length of relationship, the higher the score. Values are within 1 - 4, low to high**

# %%
# create labels for recency and length of relationship

r = range(4, 0, -1)
l = [1, 2, 3, 4]

# assign labels to 4 equal percenttile groups

r_group = pd.qcut(customers.recency, q=4, labels=r)
lor_group = pd.qcut(customers.length_of_relationship, q=5, labels=l, duplicates='drop')

# add new group columns 
best2['r_score'] = r_group
best2['lor_score'] = lor_group

best2.head()
# Out:
#             recency  length_of_relationship r_score lor_score  customer_score  \
# customerid
# 12346.0         326                       0       1         1               2
# 12347.0           2                     365       4         4               8
# 12348.0          75                     282       2         4               6
# 12349.0          19                       0       3         1               4
# 12350.0         310                       0       1         1               2
#
#            loyalty_level  cluster
# customerid
# 12346.0           Bronze        0
# 12347.0         Platinum        2
# 12348.0             Gold        1
# 12349.0           Silver        0
# 12350.0           Bronze        0

# %%
scores = ['r_score', 'lor_score']

for score in scores:
    best2[score] = best2[score].astype(int)
    
best2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4338 entries, 12346.0 to 18287.0
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   recency                 4338 non-null   int64
#  1   length_of_relationship  4338 non-null   int64
#  2   cluster                 4338 non-null   int32
#  3   r_score                 4338 non-null   int64
#  4   lor_score               4338 non-null   int64
# dtypes: int32(1), int64(4)
# memory usage: 315.4 KB

# %% [markdown]
# ### Add score values

# %%
def add_rl(x):
    return str(x['r_score'])  + str(x['lor_score'])

# %%
best2['customer_score'] = best2.apply(add_rl, axis=1)

# %%
best2.customer_score = best2.customer_score.astype(int)
best2.head()
# Out:
#             recency  length_of_relationship  cluster  r_score  lor_score  \
# customerid
# 12346.0         326                       0        0        1          1
# 12347.0           2                     365        2        4          4
# 12348.0          75                     282        1        2          4
# 12349.0          19                       0        0        3          1
# 12350.0         310                       0        0        1          1
#
#             customer_score
# customerid
# 12346.0                 11
# 12347.0                 44
# 12348.0                 24
# 12349.0                 31
# 12350.0                 11

# %% [markdown]
# ### Summing Customer Score

# %%
best2['customer_score'] = best2[['r_score', 'lor_score']].sum(axis=1)
best2.head()
# Out:
#             recency  length_of_relationship  cluster  r_score  lor_score  \
# customerid
# 12346.0         326                       0        0        1          1
# 12347.0           2                     365        2        4          4
# 12348.0          75                     282        1        2          4
# 12349.0          19                       0        0        3          1
# 12350.0         310                       0        0        1          1
#
#             customer_score
# customerid
# 12346.0                  2
# 12347.0                  8
# 12348.0                  6
# 12349.0                  4
# 12350.0                  2

# %%
best2.customer_score.describe()
# Out:
# count    4338.000000
# mean        4.710466
# std         1.998867
# min         2.000000
# 25%         3.000000
# 50%         5.000000
# 75%         6.000000
# max         8.000000
# Name: customer_score, dtype: float64

# %%
best2.stb.freq(['customer_score'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_09b00_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >customer_score</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09b00_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09b00_row0_col0" class="data row0 col0" >2</td>
#                         <td id="T_09b00_row0_col1" class="data row0 col1" >791</td>
#                         <td id="T_09b00_row0_col2" class="data row0 col2" >18.23%</td>
#                         <td id="T_09b00_row0_col3" class="data row0 col3" >791</td>
# ...

# %% [markdown]
# > **50% of the customers have customer scores of 2, 3, and 5**

# %% [markdown]
# ### Assigning Loyalty Levels to customers using customer score

# %%
Loyalty_Levels = ['Bronze', 'Silver', 'Gold', 'Platinum']
loyalty_levels = pd.qcut(best2.customer_score, q = 4, labels = Loyalty_Levels)
best2['loyalty_level'] = loyalty_levels

# %%
best2.head()
# Out:
#             recency  length_of_relationship  cluster  r_score  lor_score  \
# customerid
# 12346.0         326                       0        0        1          1
# 12347.0           2                     365        2        4          4
# 12348.0          75                     282        1        2          4
# 12349.0          19                       0        0        3          1
# 12350.0         310                       0        0        1          1
#
#             customer_score loyalty_level
# customerid
# 12346.0                  2        Bronze
# 12347.0                  8      Platinum
# 12348.0                  6          Gold
# 12349.0                  4        Silver
# 12350.0                  2        Bronze

# %%
best2.columns
# Out:
# Index(['recency', 'length_of_relationship', 'cluster', 'r_score', 'lor_score',
#        'customer_score', 'loyalty_level'],
#       dtype='object')

# %%
best2 = best2[['recency', 'length_of_relationship', 'r_score', 'lor_score', 'customer_score', 'loyalty_level']]
best2.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12346.0         326                       0        1          1
# 12347.0           2                     365        4          4
# 12348.0          75                     282        2          4
# 12349.0          19                       0        3          1
# 12350.0         310                       0        1          1
#
#             customer_score loyalty_level
# customerid
# 12346.0                  2        Bronze
# 12347.0                  8      Platinum
# 12348.0                  6          Gold
# 12349.0                  4        Silver
# 12350.0                  2        Bronze

# %% [markdown]
# ### Loyalty Level Description

# %%
best2.loyalty_level.value_counts()
# Out:
# Bronze      1492
# Silver      1265
# Platinum    1015
# Gold         566
# Name: loyalty_level, dtype: int64

# %%
best2.stb.freq(['loyalty_level'], style=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_cf896_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >loyalty_level</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >percent</th>        <th class="col_heading level0 col3" >cumulative_count</th>        <th class="col_heading level0 col4" >cumulative_percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf896_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cf896_row0_col0" class="data row0 col0" >Bronze</td>
#                         <td id="T_cf896_row0_col1" class="data row0 col1" >1,492</td>
#                         <td id="T_cf896_row0_col2" class="data row0 col2" >34.39%</td>
#                         <td id="T_cf896_row0_col3" class="data row0 col3" >1,492</td>
# ...

# %%
plt.pie(best2.loyalty_level.value_counts(), labels=best2.loyalty_level.value_counts().index, autopct='%1.1f%%')
plt.title('Loyalty Levels', weight='bold')
plt.show()

# %%
colors = ['brown', 'grey', 'gold', 'green']
plt.figure(figsize=(12, 6))
sns.set_style('whitegrid')
sns.countplot(best2.loyalty_level, palette=colors)
plt.title('Loyalty Levels', fontsize=13, weight='bold')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('loyalty level', fontsize=11, weight='bold')
plt.ylabel('count', fontsize=11, weight='bold')
plt.show()

# %% [markdown]
# ### Description of Platinum Loyalty

# %%
filta = best2.loyalty_level == 'Platinum'

platinum = best2[filta]
platinum.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12347.0           2                     365        4          4
# 12356.0          23                     302        3          4
# 12362.0           3                     292        4          4
# 12370.0          51                     309        3          4
# 12388.0          16                     311        4          4
#
#             customer_score loyalty_level  cluster
# customerid
# 12347.0                  8      Platinum        2
# 12356.0                  7      Platinum        2
# 12362.0                  8      Platinum        2
# 12370.0                  7      Platinum        1
# 12388.0                  8      Platinum        2

# %%
platinum.shape
# Out:
# (1015, 7)

# %%
platinum.describe().style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
# #T_f267c_row0_col0,#T_f267c_row0_col1,#T_f267c_row0_col2,#T_f267c_row0_col3,#T_f267c_row0_col4,#T_f267c_row0_col5{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_f267c_row1_col0{
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }#T_f267c_row1_col1{
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }#T_f267c_row1_col2,#T_f267c_row1_col3,#T_f267c_row1_col5,#T_f267c_row2_col1,#T_f267c_row2_col2,#T_f267c_row2_col3,#T_f267c_row2_col4,#T_f267c_row2_col5,#T_f267c_row3_col0,#T_f267c_row3_col2,#T_f267c_row3_col3,#T_f267c_row3_col5,#T_f267c_row4_col0,#T_f267c_row4_col2,#T_f267c_row4_col3,#T_f267c_row4_col5,#T_f267c_row5_col2,#T_f267c_row5_col3,#T_f267c_row5_col5,#T_f267c_row6_col2,#T_f267c_row6_col3,#T_f267c_row6_col5,#T_f267c_row7_col2,#T_f267c_row7_col3,#T_f267c_row7_col5{
#             background-color:  #f7fcf5;
#             color:  #000000;
# ...

# %% [markdown]
# ### Description of Gold Loyalty

# %%
gold_filta = best2.loyalty_level == 'Gold'

gold = best2[gold_filta]
gold.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12348.0          75                     282        2          4
# 12352.0          36                     260        3          3
# 12358.0           2                     149        4          2
# 12364.0           8                     104        4          2
# 12375.0          11                      87        4          2
#
#             customer_score loyalty_level  cluster
# customerid
# 12348.0                  6          Gold        1
# 12352.0                  6          Gold        1
# 12358.0                  6          Gold        2
# 12364.0                  6          Gold        2
# 12375.0                  6          Gold        2

# %%
gold.shape
# Out:
# (566, 7)

# %%
gold.describe().style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
# #T_fb361_row0_col0,#T_fb361_row0_col1,#T_fb361_row0_col2,#T_fb361_row0_col3,#T_fb361_row0_col4,#T_fb361_row0_col5{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_fb361_row1_col0{
#             background-color:  #ffefe0;
#             color:  #000000;
#         }#T_fb361_row1_col1{
#             background-color:  #fdc794;
#             color:  #000000;
#         }#T_fb361_row1_col2,#T_fb361_row4_col2,#T_fb361_row5_col2,#T_fb361_row5_col3,#T_fb361_row6_col2,#T_fb361_row6_col3,#T_fb361_row7_col2,#T_fb361_row7_col3{
#             background-color:  #fff5ea;
#             color:  #000000;
#         }#T_fb361_row1_col3,#T_fb361_row1_col5,#T_fb361_row2_col2,#T_fb361_row2_col3,#T_fb361_row2_col4,#T_fb361_row2_col5,#T_fb361_row3_col0,#T_fb361_row3_col1,#T_fb361_row3_col2,#T_fb361_row3_col3,#T_fb361_row3_col5,#T_fb361_row4_col3,#T_fb361_row4_col5,#T_fb361_row5_col5,#T_fb361_row6_col5,#T_fb361_row7_col5{
# ...

# %% [markdown]
# ### Description of Silver Loyalty

# %%
silver_filta = best2.loyalty_level == 'Silver'

silver = best2[silver_filta]
silver.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12349.0          19                       0        3          1
# 12357.0          33                       0        3          1
# 12359.0          58                     274        2          3
# 12360.0          52                     148        2          2
# 12363.0         110                     132        2          2
#
#             customer_score loyalty_level  cluster
# customerid
# 12349.0                  4        Silver        0
# 12357.0                  4        Silver        0
# 12359.0                  5        Silver        1
# 12360.0                  4        Silver        1
# 12363.0                  4        Silver        1

# %%
silver.shape
# Out:
# (1265, 7)

# %%
silver.describe().style.background_gradient(cmap='Greys')
# Out:
# <style  type="text/css" >
# #T_754a9_row0_col0,#T_754a9_row0_col1,#T_754a9_row0_col2,#T_754a9_row0_col3,#T_754a9_row0_col4,#T_754a9_row0_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_754a9_row1_col0{
#             background-color:  #fafafa;
#             color:  #000000;
#         }#T_754a9_row1_col1{
#             background-color:  #f6f6f6;
#             color:  #000000;
# ...

# %% [markdown]
# ### Description of Bronze Loyalty

# %%
bronze_filta = best2.loyalty_level == 'Bronze'

bronze = best2[bronze_filta]
bronze.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12346.0         326                       0        1          1
# 12350.0         310                       0        1          1
# 12353.0         204                       0        1          1
# 12354.0         232                       0        1          1
# 12355.0         214                       0        1          1
#
#             customer_score loyalty_level  cluster
# customerid
# 12346.0                  2        Bronze        0
# 12350.0                  2        Bronze        0
# 12353.0                  2        Bronze        0
# 12354.0                  2        Bronze        0
# 12355.0                  2        Bronze        0

# %%
bronze.shape
# Out:
# (1492, 7)

# %%
bronze.describe().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_48e9c_row0_col0,#T_48e9c_row0_col1,#T_48e9c_row0_col2,#T_48e9c_row0_col3,#T_48e9c_row0_col4,#T_48e9c_row0_col5{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_48e9c_row1_col0,#T_48e9c_row5_col0{
#             background-color:  #fee4d8;
#             color:  #000000;
#         }#T_48e9c_row1_col1{
#             background-color:  #fff4ee;
#             color:  #000000;
# ...

# %% [markdown]
# ### Distribution before Transformation

# %%
best2.hist(figsize=(8, 4), color='red')
plt.show()

# %%
best2_trans = np.log(5 + best2)
best2_trans.head()
# Out:
#              recency  length_of_relationship
# customerid
# 12346.0     5.802118                1.609438
# 12347.0     1.945910                5.913503
# 12348.0     4.382027                5.659482
# 12349.0     3.178054                1.609438
# 12350.0     5.752573                1.609438

# %% [markdown]
# ### Distribution after Transformation

# %%
best2_trans.hist(figsize=(8, 4), color='red')
plt.show()

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

best2_scaled = StandardScaler().fit_transform(best2_trans)
best2_scaled = pd.DataFrame(best2_scaled, index=best2_trans.index, columns=best2_trans.columns)
best2_scaled.head()
# Out:
#              recency  length_of_relationship
# customerid
# 12346.0     1.570258               -1.243881
# 12347.0    -1.787560                1.148304
# 12348.0     0.333704                1.007120
# 12349.0    -0.714663               -1.243881
# 12350.0     1.527116               -1.243881

# %%
best2_scaled.hist(figsize=(8, 4), color='red')
plt.show()

# %% [markdown]
# #### Elbow method for finding optimal clusters

# %%
from sklearn.cluster import KMeans

wcss = []
for k in range(1,15):
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(best2_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(14, 6))
plt.grid()
plt.plot(range(1,15), wcss, linewidth=2, color='red', marker='*')
plt.xlabel('K Values', fontsize=13, weight='bold')
plt.ylabel('WCSS', fontsize=13, weight='bold')
plt.xticks(fontsize=13, weight='bold')
plt.yticks(fontsize=13, weight='bold')
plt.show()

# %% [markdown]
# **Optimal cluster is 3**

# %%
best_kmeans = KMeans(n_clusters=3, random_state=45)
clusters = best_kmeans.fit_predict(best2_scaled)
print(clusters)
# Out:
# [0 2 1 ... 2 2 1]

# %%
best_kmeans.cluster_centers_
# Out:
# array([[ 0.66321036, -1.20270965],
#        [ 0.45628249,  0.65204034],
#        [-1.06102047,  0.77233064]])

# %% [markdown]
# ### Visualize Clusters

# %%
best2['cluster'] = clusters
best2.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12346.0         326                       0        1          1
# 12347.0           2                     365        4          4
# 12348.0          75                     282        2          4
# 12349.0          19                       0        3          1
# 12350.0         310                       0        1          1
#
#             customer_score loyalty_level  cluster
# customerid
# 12346.0                  2        Bronze        0
# 12347.0                  8      Platinum        2
# 12348.0                  6          Gold        1
# 12349.0                  4        Silver        0
# 12350.0                  2        Bronze        0

# %% [markdown]
# ### Cluster Description

# %% [markdown]
# ### Description of Cluster 0

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.countplot(best2.cluster)
plt.title('Cluster Count', fontsize=12, weight='bold')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 0 description

# %%
filta0 = best2.cluster == 0

cluster0 = best2[filta0]
cluster0.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12346.0         326                       0        1          1
# 12349.0          19                       0        3          1
# 12350.0         310                       0        1          1
# 12353.0         204                       0        1          1
# 12354.0         232                       0        1          1
#
#             customer_score loyalty_level  cluster
# customerid
# 12346.0                  2        Bronze        0
# 12349.0                  4        Silver        0
# 12350.0                  2        Bronze        0
# 12353.0                  2        Bronze        0
# 12354.0                  2        Bronze        0

# %%
cluster0[['recency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_03263_row0_col0,#T_03263_row0_col1,#T_03263_row0_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_03263_row1_col0{
#             background-color:  #fee6da;
#             color:  #000000;
#         }#T_03263_row1_col1,#T_03263_row1_col2,#T_03263_row2_col1,#T_03263_row2_col2,#T_03263_row3_col0,#T_03263_row3_col1,#T_03263_row3_col2,#T_03263_row4_col1,#T_03263_row4_col2,#T_03263_row5_col1,#T_03263_row5_col2,#T_03263_row6_col1,#T_03263_row6_col2,#T_03263_row7_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_03263_row2_col0{
#             background-color:  #feeae1;
#             color:  #000000;
#         }#T_03263_row4_col0{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_03263_row5_col0{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_03263_row6_col0{
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(cluster0.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster0 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 1 Description

# %%
filta1 = best2.cluster == 1

cluster1 = best2[filta1]
cluster1.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12348.0          75                     282        2          4
# 12352.0          36                     260        3          3
# 12359.0          58                     274        2          3
# 12360.0          52                     148        2          2
# 12363.0         110                     132        2          2
#
#             customer_score loyalty_level  cluster
# customerid
# 12348.0                  6          Gold        1
# 12352.0                  6          Gold        1
# 12359.0                  5        Silver        1
# 12360.0                  4        Silver        1
# 12363.0                  4        Silver        1

# %%
cluster1[['recency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='BuPu')
# Out:
# <style  type="text/css" >
# #T_676da_row0_col0,#T_676da_row0_col1,#T_676da_row0_col2{
#             background-color:  #4d004b;
#             color:  #f1f1f1;
#         }#T_676da_row1_col0{
#             background-color:  #ebf4f8;
#             color:  #000000;
#         }#T_676da_row1_col1{
#             background-color:  #dfebf4;
#             color:  #000000;
#         }#T_676da_row1_col2,#T_676da_row2_col2,#T_676da_row3_col0,#T_676da_row3_col1,#T_676da_row3_col2,#T_676da_row4_col2,#T_676da_row5_col2,#T_676da_row6_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_676da_row2_col0{
#             background-color:  #f1f8fb;
#             color:  #000000;
#         }#T_676da_row2_col1{
#             background-color:  #edf5f9;
#             color:  #000000;
#         }#T_676da_row4_col0{
#             background-color:  #f4fafc;
#             color:  #000000;
#         }#T_676da_row4_col1{
#             background-color:  #ebf3f8;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(cluster1.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster1 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 2 Description

# %%
filta2 = best2.cluster == 2

cluster2 = best2[filta2]
cluster2.head()
# Out:
#             recency  length_of_relationship  r_score  lor_score  \
# customerid
# 12347.0           2                     365        4          4
# 12356.0          23                     302        3          4
# 12358.0           2                     149        4          2
# 12362.0           3                     292        4          4
# 12364.0           8                     104        4          2
#
#             customer_score loyalty_level  cluster
# customerid
# 12347.0                  8      Platinum        2
# 12356.0                  7      Platinum        2
# 12358.0                  6          Gold        2
# 12362.0                  8      Platinum        2
# 12364.0                  6          Gold        2

# %%
cluster2[['recency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
# #T_97968_row0_col0,#T_97968_row0_col1,#T_97968_row0_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_97968_row1_col0,#T_97968_row2_col0,#T_97968_row5_col0,#T_97968_row6_col2,#T_97968_row7_col2{
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }#T_97968_row1_col1{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_97968_row1_col2,#T_97968_row2_col2,#T_97968_row3_col0,#T_97968_row3_col1,#T_97968_row3_col2,#T_97968_row4_col0,#T_97968_row4_col2,#T_97968_row5_col2{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_97968_row2_col1{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_97968_row4_col1{
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }#T_97968_row5_col1{
#             background-color:  #daf0d4;
#             color:  #000000;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(cluster2.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster2 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Clusters Comparisom and Differences

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))
sns.countplot(best2.cluster, hue=best2.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Cluster', fontsize=12, weight='bold')
plt.ylabel('Loyalty Level Count', fontsize=12, weight='bold')
plt.title('Loyalty Level per Clusters', weight='bold')
plt.show()

# %%
colors = ['red', 'blue', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))
sns.countplot(best2.loyalty_level, hue=best2.cluster, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Loyalty Level Count', fontsize=12, weight='bold')
plt.title('Loyalty Level per Clusters', weight='bold', fontsize=13)
plt.show()

# %% [markdown]
# <div class='alert alert-success'>
#
# <h2>Cluster Ranking according to the composition of loyalty levels:</h2>
#
# <li>Cluster 2</li>
# <li>Cluster 1</li>
# <li>Cluster 0</li>
#
# </div>

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='recency', y='length_of_relationship', data=best2, palette=colors)

# %%
plt.figure(figsize=(14, 6))
plt.scatter(best2.recency, best2.length_of_relationship, c=best_kmeans.labels_, cmap='rainbow')
plt.scatter(best_kmeans.cluster_centers_[:, 0], best_kmeans.cluster_centers_[:, 1], color='black')
plt.title('Customer Clusters (Recency x Length of Relationship)', fontsize=13, weight='bold')
plt.xlabel('Recency', fontsize=12, weight='bold')
plt.ylabel('Length of Relationship', fontsize=12, weight='bold')
plt.xticks(fontsize=13, weight='bold')
plt.yticks(fontsize=13, weight='bold')
plt.show()

# %%
colors = ['red', 'green', 'blue']
color = ['blue', 'red', 'green']

plt.figure(figsize=(14, 6))
sns.scatterplot(x='recency', y='length_of_relationship', data=best2, hue='cluster', palette=colors)
plt.title('Cluster plot of Recency & Length of Relationship', fontsize=13, weight='bold')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Recency', fontsize=12, weight='bold')
plt.ylabel('Length of Relationship', fontsize=12, weight='bold')
plt.show()

# %% [markdown]
# <div class='alert alert-danger'></div>

# %% [markdown]
# <div class='alert alert-warning'></div>

# %% [markdown]
# ### Clustering using frequency and monetary scores

# %% [markdown]
# ### Transformation

# %%
plt.figure(figsize=(7, 7))

#frequency plot
plt.subplot(2, 1, 1)
plt.title('Pre Transformation Frequency X Monetary')
sns.distplot(customers.frequency)

#monetary value plot
plt.subplot(2, 1, 2)
sns.distplot(customers.monetary)

plt.show()

# %% [markdown]
# > StandardScaler test

# %%
customers[['frequency', 'monetary']].head()
# Out:
#             frequency  monetary
# customerid
# 12346.0             1  77183.60
# 12347.0           182   4310.00
# 12348.0            31   1797.24
# 12349.0            73   1757.55
# 12350.0            17    334.40

# %%
trans_fm = np.log(customers[['frequency', 'monetary']])
trans_fm.head()
# Out:
#             frequency   monetary
# customerid
# 12346.0      0.000000  11.253942
# 12347.0      5.204007   8.368693
# 12348.0      3.433987   7.494007
# 12349.0      4.290459   7.471676
# 12350.0      2.833213   5.812338

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler().fit_transform(customers[['frequency', 'monetary']])
std_scaler = pd.DataFrame(std_scaler, index=trans_fm.index, columns=trans_fm.columns)
std_scaler.head()
# Out:
#             frequency  monetary
# customerid
# 12346.0     -0.396578  8.358668
# 12347.0      0.394649  0.250966
# 12348.0     -0.265435 -0.028596
# 12349.0     -0.081836 -0.033012
# 12350.0     -0.326635 -0.191347

# %%
plt.figure(figsize=(7, 7))

#frequency plot
plt.subplot(2, 1, 1)
plt.title('Standard Scaled Frequency X Monetary')
sns.distplot(std_scaler.frequency)

#monetary value plot
plt.subplot(2, 1, 2)
sns.distplot(std_scaler.monetary)

plt.show()

# %%
plt.figure(figsize=(7, 7))

#frequency plot
plt.subplot(2, 1, 1)
plt.title('Transformed Frequency X Monetary')
sns.distplot(trans_fm.frequency)

#monetary value plot
plt.subplot(2, 1, 2)
sns.distplot(trans_fm.monetary)

plt.show()

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaled_fm = StandardScaler().fit_transform(trans_fm)
scaled_fm = pd.DataFrame(scaled_fm, index=trans_fm.index, columns=trans_fm.columns)
scaled_fm.head()
# Out:
#             frequency  monetary
# customerid
# 12346.0     -2.775160  3.698719
# 12347.0      1.149549  1.410201
# 12348.0     -0.185347  0.716419
# 12349.0      0.460579  0.698706
# 12350.0     -0.638433 -0.617446

# %%
plt.figure(figsize=(7, 7))


#frequency plot
plt.subplot(2, 1, 1)
plt.title('Scaled Frequency X Monetary')
sns.distplot(scaled_fm.frequency)

#monetary value plot
plt.subplot(2, 1, 2)
sns.distplot(scaled_fm.monetary)
plt.show()

# %% [markdown]
# #### Elbow method for finding optimal clusters

# %%
x_sc_fm = scaled_fm[['frequency', 'monetary']]
x_sc_fm.head()
# Out:
#             frequency  monetary
# customerid
# 12346.0     -2.775160  3.698719
# 12347.0      1.149549  1.410201
# 12348.0     -0.185347  0.716419
# 12349.0      0.460579  0.698706
# 12350.0     -0.638433 -0.617446

# %%
from sklearn.cluster import KMeans

wcss = []
for k in range(1,15):
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(x_sc_fm)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(14, 6))
plt.grid()
plt.plot(range(1,15), wcss, linewidth=2, color='red', marker='*')
plt.xlabel('K Values', fontsize=13, weight='bold')
plt.ylabel('WCSS', fontsize=13, weight='bold')
plt.xticks(fontsize=13, weight='bold')
plt.yticks(fontsize=13, weight='bold')
plt.show()

# %% [markdown]
# ### Optimum clusters: 3

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
cluster = kmeans.fit_predict(x_sc_fm)
print(cluster)
# Out:
# [0 0 2 ... 1 0 0]

# %% [markdown]
# Centroids

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.11975258,  1.21712566],
#        [-1.13556269, -1.02688701],
#        [ 0.07553928, -0.05563155]])

# %% [markdown]
# ### Visualize Clusters

# %%
x_sc_fm['cluster'] = cluster
x_sc_fm.head()
# Out:
#             frequency  monetary  cluster
# customerid
# 12346.0     -2.775160  3.698719        0
# 12347.0      1.149549  1.410201        0
# 12348.0     -0.185347  0.716419        2
# 12349.0      0.460579  0.698706        0
# 12350.0     -0.638433 -0.617446        1

# %%
customers['cluster'] = cluster
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score loyalty_level  cluster
# customerid
# 12346.0           4        1          1               7        Silver        0
# 12347.0           4        4          4              16      Platinum        0
# 12348.0           4        2          4              12          Gold        2
# 12349.0           4        3          1              11          Gold        0
# 12350.0           2        1          1               5        Bronze        1

# %%
plt.figure(figsize=(14, 6))
plt.scatter(x_sc_fm.frequency, x_sc_fm.monetary)
plt.title('Frequency x Monetary')
plt.show()

# %%
x_sc_fm.frequency.corr(x_sc_fm.monetary).round(2)
# Out:
# 0.76

# %%
plt.figure(figsize=(14, 6))
plt.scatter(x_sc_fm.frequency, x_sc_fm.monetary, c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color='black')
plt.title('Customer Clusters (Frequency x Monetary)', fontsize=13, weight='bold')
plt.xlabel('Frequency', fontsize=12, weight='bold')
plt.ylabel('Monetary', fontsize=12, weight='bold')
plt.xticks(fontsize=13, weight='bold')
plt.yticks(fontsize=13, weight='bold')
plt.show()

# %%
colors = ['red', 'green', 'blue']
color = ['blue', 'red', 'green']

plt.figure(figsize=(14, 6))
sns.scatterplot(x='frequency', y='monetary', data=x_sc_fm, hue='cluster', palette=colors)
sns.scatterplot(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], palette=color, hue=range(3), s=100, ec='black')
plt.title('Cluster plot of Frequency x Monetary', fontsize=13, weight='bold')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('frequency', fontsize=12, weight='bold')
plt.ylabel('monetary', fontsize=12, weight='bold')
plt.show()

# %% [markdown]
# ###  Description of Clusters

# %%
sns.set_style('whitegrid')
sns.countplot(x_sc_fm.cluster)
plt.title('Cluster Count')
plt.show()

# %% [markdown]
# ### Cluster 0 description

# %%
filta = customers.cluster == 0

cluster0 = customers[filta]
cluster0.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12349.0          19         73   1757.55                       0        3
# 12352.0          36         85   2506.04                     260        3
# 12356.0          23         59   2811.43                     302        3
#
#             m_score  f_score  lor_score  customer_score loyalty_level  cluster
# customerid
# 12346.0           4        1          1               7        Silver        0
# 12347.0           4        4          4              16      Platinum        0
# 12349.0           4        3          1              11          Gold        0
# 12352.0           4        3          3              13          Gold        0
# 12356.0           4        3          4              14      Platinum        0

# %%
cluster0[['recency', 'frequency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_78104_row0_col0,#T_78104_row0_col2,#T_78104_row0_col3,#T_78104_row7_col1{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_78104_row0_col1{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_78104_row1_col0,#T_78104_row1_col1{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_78104_row1_col2{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_78104_row1_col3,#T_78104_row4_col3,#T_78104_row5_col3{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_78104_row2_col0{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_78104_row2_col1{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_78104_row2_col2{
#             background-color:  #fee7dc;
#             color:  #000000;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(cluster0.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster0 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 1 description

# %%
filt = customers.cluster == 1

cluster1 = customers[filt]
cluster1.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12350.0         310         17     334.4                       0        1
# 12353.0         204          4      89.0                       0        1
# 12355.0         214         13     459.4                       0        1
# 12361.0         287         10     189.9                       0        1
# 12367.0           4         11     168.9                       0        4
#
#             m_score  f_score  lor_score  customer_score loyalty_level  cluster
# customerid
# 12350.0           2        1          1               5        Bronze        1
# 12353.0           1        1          1               4        Bronze        1
# 12355.0           2        1          1               5        Bronze        1
# 12361.0           1        1          1               4        Bronze        1
# 12367.0           1        1          1               7        Silver        1

# %%
cluster1[['recency', 'frequency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
# #T_89abe_row0_col0,#T_89abe_row0_col1,#T_89abe_row0_col2,#T_89abe_row0_col3{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }#T_89abe_row1_col0{
#             background-color:  #fee7d0;
#             color:  #000000;
#         }#T_89abe_row1_col1,#T_89abe_row7_col3{
#             background-color:  #fff4e9;
#             color:  #000000;
#         }#T_89abe_row1_col2{
#             background-color:  #fff3e6;
#             color:  #000000;
#         }#T_89abe_row1_col3,#T_89abe_row2_col3,#T_89abe_row3_col0,#T_89abe_row3_col1,#T_89abe_row3_col2,#T_89abe_row3_col3,#T_89abe_row4_col2,#T_89abe_row4_col3,#T_89abe_row5_col2,#T_89abe_row5_col3,#T_89abe_row6_col2{
#             background-color:  #fff5eb;
#             color:  #000000;
#         }#T_89abe_row2_col0{
#             background-color:  #feead6;
#             color:  #000000;
#         }#T_89abe_row2_col1,#T_89abe_row4_col1,#T_89abe_row5_col1,#T_89abe_row6_col3{
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(cluster1.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster1 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 2 description

# %%
fil = customers.cluster == 2

cluster2 = customers[fil]
cluster2.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12348.0          75         31   1797.24                     282        2
# 12354.0         232         58   1079.40                       0        1
# 12358.0           2         19   1168.06                     149        4
# 12363.0         110         23    552.00                     132        2
# 12364.0           8         85   1313.10                     104        4
#
#             m_score  f_score  lor_score  customer_score loyalty_level  cluster
# customerid
# 12348.0           4        2          4              12          Gold        2
# 12354.0           3        3          1               8        Silver        2
# 12358.0           3        2          2              11          Gold        2
# 12363.0           2        2          2               8        Silver        2
# 12364.0           3        3          2              12          Gold        2

# %%
cluster2[['recency', 'frequency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_e02b7_row0_col0,#T_e02b7_row0_col1,#T_e02b7_row0_col2,#T_e02b7_row0_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_e02b7_row1_col0,#T_e02b7_row2_col0,#T_e02b7_row5_col2{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_e02b7_row1_col1{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_e02b7_row1_col2,#T_e02b7_row2_col2{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_e02b7_row1_col3,#T_e02b7_row2_col3,#T_e02b7_row3_col0,#T_e02b7_row3_col1,#T_e02b7_row3_col2,#T_e02b7_row3_col3,#T_e02b7_row4_col2,#T_e02b7_row4_col3{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_e02b7_row2_col1,#T_e02b7_row4_col1{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_e02b7_row4_col0{
#             background-color:  #f5fafe;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(cluster2.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster2 loyalty level count', weight='bold')
plt.show()

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))
sns.countplot(customers.cluster, hue=customers.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Clusters', fontsize=12, weight='bold')
plt.ylabel('Loyalty Level Count', fontsize=12, weight='bold')
plt.title('Loyalty Level per Clusters', weight='bold')
plt.show()

# %%
colors = ['green', 'red', 'blue']

sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))
sns.countplot(customers.loyalty_level, hue=customers.cluster, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Loyalty Level Count', fontsize=12, weight='bold')
plt.title('Loyalty Level per Clusters', weight='bold', fontsize=13)
plt.show()

# %% [markdown]
# ### Cluster Levels
#
# - cluster 0
# - cluster 2
# - cluster 1

# %% [markdown]
# <div class='alert alert-warning'></div>

# %% [markdown]
# <div class='alert alert-info'></div>

# %% [markdown]
# ## Clustering using ALL CUSTOMER SCORING METRICS

# %% [markdown]
# ### Transformation

# %%
data_copy.head()
# Out:
#             recency  frequency  monetary  length_of_relationship
# customerid
# 12346.0         326          1  77183.60                       0
# 12347.0           2        182   4310.00                     365
# 12348.0          75         31   1797.24                     282
# 12349.0          19         73   1757.55                       0
# 12350.0         310         17    334.40                       0

# %%
plt.figure(figsize=(7, 7))

#frequency plot
plt.subplot(4, 1, 1)
plt.title('Transformed Frequency X Monetary X Recency X Length of Relationship')
sns.distplot(data_copy.frequency)

#monetary value plot
plt.subplot(4, 1, 2)
sns.distplot(data_copy.monetary)

#recency value plot
plt.subplot(4, 1, 3)
sns.distplot(data_copy.recency)

#length of relationship value plot
plt.subplot(4, 1, 4)
sns.distplot(data_copy.length_of_relationship)

plt.show()

# %% [markdown]
# #### Log transformation of Values

# %%
data_copy_trans = np.log(5 + data_copy)
data_copy_trans.head()
# Out:
#              recency  frequency   monetary  length_of_relationship
# customerid
# 12346.0     5.802118   1.791759  11.254007                1.609438
# 12347.0     1.945910   5.231109   8.369853                5.913503
# 12348.0     4.382027   3.583519   7.496786                5.659482
# 12349.0     3.178054   4.356709   7.474517                1.609438
# 12350.0     5.752573   3.091042   5.827179                1.609438

# %%
plt.figure(figsize=(7, 7))

#frequency plot
plt.subplot(4, 1, 1)
plt.title('Transformed Frequency X Monetary X Recency X Length of Relationship')
sns.distplot(data_copy_trans.frequency)

#monetary value plot
plt.subplot(4, 1, 2)
sns.distplot(data_copy_trans.monetary)

#recency value plot
plt.subplot(4, 1, 3)
sns.distplot(data_copy_trans.recency)

#length of relationship value plot
plt.subplot(4, 1, 4)
sns.distplot(data_copy_trans.length_of_relationship)

plt.show()

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

data_copy_sc = StandardScaler().fit_transform(data_copy_trans)
data_copy_sc = pd.DataFrame(data_copy_sc, index=data_copy_trans.index, columns=data_copy_trans.columns)
data_copy_sc.head()
# Out:
#              recency  frequency  monetary  length_of_relationship
# customerid
# 12346.0     1.570258  -1.937688  3.733464               -1.243881
# 12347.0    -1.787560   1.224120  1.417481                1.148304
# 12348.0     0.333704  -0.290516  0.716407                1.007120
# 12349.0    -0.714663   0.420280  0.698525               -1.243881
# 12350.0     1.527116  -0.743252 -0.624291               -1.243881

# %%
plt.figure(figsize=(7, 7))

#frequency plot
plt.subplot(4, 1, 1)
plt.title('Scaled Frequency X Monetary X Recency X Length of Relationship')
sns.distplot(data_copy_sc.frequency)

#monetary value plot
plt.subplot(4, 1, 2)
sns.distplot(data_copy_sc.monetary)

#recency value plot
plt.subplot(4, 1, 3)
sns.distplot(data_copy_sc.recency)

#length of relationship value plot
plt.subplot(4, 1, 4)
sns.distplot(data_copy_sc.length_of_relationship)

plt.show()

# %% [markdown]
# #### Elbow method for finding optimal clusters

# %%
from sklearn.cluster import KMeans

wcss = []
for k in range(1,15):
    kmeans = KMeans(n_clusters=k, init='k-means++')
    kmeans.fit(data_copy_sc)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(14, 6))
plt.grid()
plt.plot(range(1,15), wcss, linewidth=2, color='red', marker='*')
plt.xlabel('K Values', fontsize=13, weight='bold')
plt.ylabel('WCSS', fontsize=13, weight='bold')
plt.xticks(fontsize=13, weight='bold')
plt.yticks(fontsize=13, weight='bold')
plt.show()

# %% [markdown]
# #### Optimal Cluster number = 3

# %%
kmeanss = KMeans(n_clusters=3, random_state=42)
cluster3 = kmeanss.fit_predict(data_copy_sc)
print(cluster3)
# Out:
# [1 0 2 ... 2 0 2]

# %% [markdown]
# #### Cluster Centroids

# %%
kmeanss.cluster_centers_
# Out:
# array([[-0.95260247,  1.18181868,  1.15015944,  0.91519316],
#        [ 0.6521537 , -0.79007452, -0.82762695, -1.17086333],
#        [ 0.01433798, -0.03838183,  0.02628572,  0.57617257]])

# %%
customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score loyalty_level  cluster
# customerid
# 12346.0           4        1          1               7        Silver        0
# 12347.0           4        4          4              16      Platinum        0
# 12348.0           4        2          4              12          Gold        2
# 12349.0           4        3          1              11          Gold        0
# 12350.0           2        1          1               5        Bronze        1

# %%
new_customers = customers.copy()
new_customers['cluster'] = cluster3
new_customers.head()
# Out:
#             recency  frequency  monetary  length_of_relationship  r_score  \
# customerid
# 12346.0         326          1  77183.60                       0        1
# 12347.0           2        182   4310.00                     365        4
# 12348.0          75         31   1797.24                     282        2
# 12349.0          19         73   1757.55                       0        3
# 12350.0         310         17    334.40                       0        1
#
#             m_score  f_score  lor_score  customer_score loyalty_level  cluster
# customerid
# 12346.0           4        1          1               7        Silver        1
# 12347.0           4        4          4              16      Platinum        0
# 12348.0           4        2          4              12          Gold        2
# 12349.0           4        3          1              11          Gold        2
# 12350.0           2        1          1               5        Bronze        1

# %%
new_customers_pca2 = new_customers[['recency', 'frequency', 'monetary', 'length_of_relationship']]
new_customers_pca2.head()
# Out:
#             recency  frequency  monetary  length_of_relationship
# customerid
# 12346.0         326          1  77183.60                       0
# 12347.0           2        182   4310.00                     365
# 12348.0          75         31   1797.24                     282
# 12349.0          19         73   1757.55                       0
# 12350.0         310         17    334.40                       0

# %% [markdown]
# ### Principal Components Analysis
#
#
# > reducing the variable space of 4 to 2 for plotting

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2, random_state=4)
pca_components = pd.DataFrame(pca.fit_transform(new_customers_pca2), index=new_customers.index)
pca_components.rename(columns={0: 'pca1', 1: 'pca2'}, inplace=True)
pca_components.head()
# Out:
#                     pca1         pca2
# customerid
# 12346.0     75122.785120 -1005.187474
# 12347.0      2257.460271   135.798015
# 12348.0      -257.136072   -12.170704
# 12349.0      -297.231417   -38.715054
# 12350.0     -1721.287543  -117.413665

# %%
pca_components.shape
# Out:
# (4338, 2)

# %%
new_customers_pca2.shape
# Out:
# (4338, 4)

# %%
new_customers.loyalty_level
# Out:
# customerid
# 12346.0      Silver
# 12347.0    Platinum
# 12348.0        Gold
# 12349.0        Gold
# 12350.0      Bronze
#              ...
# 18280.0      Bronze
# 18281.0      Bronze
# 18282.0      Silver
# 18283.0    Platinum
# 18287.0        Gold
# Name: loyalty_level, Length: 4338, dtype: category
# Categories (4, object): ['Bronze' < 'Silver' < 'Gold' < 'Platinum']

# %%
pca_components['loyalty_level'] = new_customers.loyalty_level
pca_components['cluster'] = new_customers.cluster
pca_components[['recency', 'frequency', 'monetary', 'length_of_relationship']] = new_customers_pca2[['recency', 'frequency', 'monetary', 'length_of_relationship']]
pca_components['customer_score'] = customers['customer_score']

pca_components.head()
# Out:
#                     pca1         pca2 loyalty_level  cluster  recency  \
# customerid
# 12346.0     75122.785120 -1005.187474        Silver        1      326
# 12347.0      2257.460271   135.798015      Platinum        0        2
# 12348.0      -257.136072   -12.170704          Gold        2       75
# 12349.0      -297.231417   -38.715054          Gold        2       19
# 12350.0     -1721.287543  -117.413665        Bronze        1      310
#
#             frequency  monetary  length_of_relationship  customer_score
# customerid
# 12346.0             1  77183.60                       0               7
# 12347.0           182   4310.00                     365              16
# 12348.0            31   1797.24                     282              12
# 12349.0            73   1757.55                       0              11
# 12350.0            17    334.40                       0               5

# %%
colors = ['green', 'red', 'blue']

plt.figure(figsize=(14, 6))
sns.scatterplot(x='pca1', y='pca2', data=pca_components, hue='cluster', s=150, palette=colors)
plt.title('Cluster plot PCA1 x PCA2', fontsize=13, weight='bold')
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('pca1', fontsize=12, weight='bold')
plt.ylabel('pca2', fontsize=12, weight='bold')
plt.show()

# %% [markdown]
# ###  Description of Clusters

# %%
sns.set_style('whitegrid')
sns.countplot(pca_components.cluster)
plt.title('Cluster Count')
plt.show()

# %% [markdown]
# ### Cluster 0 description

# %%
filta0 = pca_components.cluster == 0

c0 = pca_components[filta0]
c0.head()
# Out:
#                    pca1        pca2 loyalty_level  cluster  recency  \
# customerid
# 12347.0     2257.460271  135.798015      Platinum        0        2
# 12352.0      452.178902   30.983798          Gold        0       36
# 12356.0      757.426818   15.760551      Platinum        0       23
# 12357.0     4153.207305  -35.807618          Gold        0       33
# 12359.0     4320.239301  143.185365          Gold        0       58
#
#             frequency  monetary  length_of_relationship  customer_score
# customerid
# 12347.0           182   4310.00                     365              16
# 12352.0            85   2506.04                     260              13
# 12356.0            59   2811.43                     302              14
# 12357.0           131   6207.67                       0              12
# 12359.0           248   6372.58                     274              13

# %%
c0[['recency', 'frequency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_81a03_row0_col0,#T_81a03_row0_col2,#T_81a03_row0_col3,#T_81a03_row7_col1{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_81a03_row0_col1{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_81a03_row1_col0,#T_81a03_row2_col0{
#             background-color:  #fff2ec;
#             color:  #000000;
#         }#T_81a03_row1_col1{
#             background-color:  #fff0e9;
#             color:  #000000;
#         }#T_81a03_row1_col2{
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }#T_81a03_row1_col3,#T_81a03_row4_col3,#T_81a03_row5_col0{
#             background-color:  #fff4ee;
#             color:  #000000;
#         }#T_81a03_row2_col1{
#             background-color:  #ffece4;
#             color:  #000000;
#         }#T_81a03_row2_col2{
#             background-color:  #fee7dc;
#             color:  #000000;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(c0.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster0 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 1 description

# %%
filta2 = pca_components.cluster == 1

c1 = pca_components[filta2]
c1.head()
# Out:
#                     pca1         pca2 loyalty_level  cluster  recency  \
# customerid
# 12346.0     75122.785120 -1005.187474        Silver        1      326
# 12350.0     -1721.287543  -117.413665        Bronze        1      310
# 12353.0     -1966.667444  -111.937829        Bronze        1      204
# 12354.0      -975.788639   -75.658854        Silver        1      232
# 12355.0     -1596.208074  -108.975797        Bronze        1      214
#
#             frequency  monetary  length_of_relationship  customer_score
# customerid
# 12346.0             1   77183.6                       0               7
# 12350.0            17     334.4                       0               5
# 12353.0             4      89.0                       0               4
# 12354.0            58    1079.4                       0               8
# 12355.0            13     459.4                       0               5

# %%
c1[['recency', 'frequency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
# #T_11d41_row0_col0,#T_11d41_row0_col1,#T_11d41_row0_col2,#T_11d41_row0_col3{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_11d41_row1_col0,#T_11d41_row7_col1{
#             background-color:  #e9f7e5;
#             color:  #000000;
#         }#T_11d41_row1_col1,#T_11d41_row2_col1{
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }#T_11d41_row1_col2,#T_11d41_row1_col3,#T_11d41_row2_col3,#T_11d41_row3_col0,#T_11d41_row3_col1,#T_11d41_row3_col2,#T_11d41_row3_col3,#T_11d41_row4_col2,#T_11d41_row4_col3,#T_11d41_row5_col2,#T_11d41_row5_col3,#T_11d41_row6_col2,#T_11d41_row6_col3{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_11d41_row2_col0{
#             background-color:  #edf8ea;
#             color:  #000000;
#         }#T_11d41_row2_col2,#T_11d41_row4_col1,#T_11d41_row5_col1,#T_11d41_row7_col3{
#             background-color:  #f6fcf4;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(c1.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster1 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Cluster 2 description

# %%
filta3 = pca_components.cluster == 2

c2 = pca_components[filta3]
c2.head()
# Out:
#                    pca1       pca2 loyalty_level  cluster  recency  frequency  \
# customerid
# 12348.0     -257.136072 -12.170704          Gold        2       75         31
# 12349.0     -297.231417 -38.715054          Gold        2       19         73
# 12358.0     -886.746638 -41.468888          Gold        2        2         19
# 12363.0    -1502.927286 -50.575983        Silver        2      110         23
# 12371.0     -166.926178 -49.702919          Gold        2       45         63
#
#             monetary  length_of_relationship  customer_score
# customerid
# 12348.0      1797.24                     282              12
# 12349.0      1757.55                       0              11
# 12358.0      1168.06                     149              11
# 12363.0       552.00                     132               8
# 12371.0      1887.96                      14              11

# %%
c2[['recency', 'frequency', 'length_of_relationship', 'customer_score']].describe().style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_d57f9_row0_col0,#T_d57f9_row0_col1,#T_d57f9_row0_col2,#T_d57f9_row0_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_d57f9_row1_col0,#T_d57f9_row2_col0,#T_d57f9_row6_col1{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_d57f9_row1_col1{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_d57f9_row1_col2,#T_d57f9_row5_col2{
#             background-color:  #e2edf8;
#             color:  #000000;
#         }#T_d57f9_row1_col3,#T_d57f9_row4_col3,#T_d57f9_row5_col3,#T_d57f9_row6_col3{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_d57f9_row2_col1{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_d57f9_row2_col2{
#             background-color:  #ebf3fb;
#             color:  #000000;
# ...

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(7, 4))
sns.countplot(c2.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Count', fontsize=12, weight='bold')
plt.title('Cluster2 loyalty level count', weight='bold')
plt.show()

# %% [markdown]
# ### Clusters Comparisom and Differences

# %%
colors = ['brown', 'grey', 'gold', 'green']

sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))
sns.countplot(pca_components.cluster, hue=pca_components.loyalty_level, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Cluster', fontsize=12, weight='bold')
plt.ylabel('Loyalty Level Count', fontsize=12, weight='bold')
plt.title('Loyalty Level per Clusters', weight='bold')
plt.show()

# %%
colors = ['green', 'red', 'blue']

sns.set_style('whitegrid')
plt.figure(figsize=(14, 6))
sns.countplot(pca_components.loyalty_level, hue=pca_components.cluster, palette=colors)
plt.xticks(fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')
plt.xlabel('Loyalty Level', fontsize=12, weight='bold')
plt.ylabel('Loyalty Level Count', fontsize=12, weight='bold')
plt.title('Loyalty Level per Clusters', weight='bold', fontsize=13)
plt.show()

# %% [markdown]
# ### Cluster Ranking according to the composition loyalty levels:
#
# - Cluster 0
# - Cluster 2
# - Cluster 1

# %% [markdown]
# <div class='alert alert-info'></div>

# %%
data.head()
# Out:
#    invoiceno stockcode                          description  quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  unitprice  customerid         country  sales  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
#
#          invoicedate2
# 0 2010-12-01 08:26:00
# 1 2010-12-01 08:26:00
# 2 2010-12-01 08:26:00
# 3 2010-12-01 08:26:00
# ...

# %%
data_update = data.copy()
data_update.set_index('customerid', inplace=True)
data_update.head()
# Out:
#             invoiceno stockcode                          description  \
# customerid
# 17850.0        536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 17850.0        536365     71053                  WHITE METAL LANTERN
# 17850.0        536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 17850.0        536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 17850.0        536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#             quantity         invoicedate  unitprice         country  sales  \
# customerid
# 17850.0            6 2010-12-01 08:26:00       2.55  United Kingdom  15.30
# 17850.0            6 2010-12-01 08:26:00       3.39  United Kingdom  20.34
# 17850.0            8 2010-12-01 08:26:00       2.75  United Kingdom  22.00
# 17850.0            6 2010-12-01 08:26:00       3.39  United Kingdom  20.34
# 17850.0            6 2010-12-01 08:26:00       3.39  United Kingdom  20.34
#
#                   invoicedate2
# customerid
# ...

# %% [markdown]
# ### Merge new customer values with original data

# %%
update = pd.merge(data_update, pca_components, how='right', left_on='customerid', right_on='customerid')

# %%
update.head()
# Out:
#             invoiceno stockcode                        description  quantity  \
# customerid
# 12346.0        541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 12347.0        537626     85116    BLACK CANDELABRA T-LIGHT HOLDER        12
# 12347.0        537626     22375  AIRLINE BAG VINTAGE JET SET BROWN         4
# 12347.0        537626     71477  COLOUR GLASS. STAR T-LIGHT HOLDER        12
# 12347.0        537626     22492            MINI PAINT SET VINTAGE         36
#
#                    invoicedate  unitprice         country    sales  \
# customerid
# 12346.0    2011-01-18 10:01:00       1.04  United Kingdom  77183.6
# 12347.0    2010-12-07 14:57:00       2.10         Iceland     25.2
# 12347.0    2010-12-07 14:57:00       4.25         Iceland     17.0
# 12347.0    2010-12-07 14:57:00       3.25         Iceland     39.0
# 12347.0    2010-12-07 14:57:00       0.65         Iceland     23.4
#
# ...

# %%
update.drop(['pca1', 'pca2'], axis=1, inplace=True)
update.head()
# Out:
#             invoiceno stockcode                        description  quantity  \
# customerid
# 12346.0        541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 12347.0        537626     85116    BLACK CANDELABRA T-LIGHT HOLDER        12
# 12347.0        537626     22375  AIRLINE BAG VINTAGE JET SET BROWN         4
# 12347.0        537626     71477  COLOUR GLASS. STAR T-LIGHT HOLDER        12
# 12347.0        537626     22492            MINI PAINT SET VINTAGE         36
#
#                    invoicedate  unitprice         country    sales  \
# customerid
# 12346.0    2011-01-18 10:01:00       1.04  United Kingdom  77183.6
# 12347.0    2010-12-07 14:57:00       2.10         Iceland     25.2
# 12347.0    2010-12-07 14:57:00       4.25         Iceland     17.0
# 12347.0    2010-12-07 14:57:00       3.25         Iceland     39.0
# 12347.0    2010-12-07 14:57:00       0.65         Iceland     23.4
#
# ...

# %% [markdown]
# ### Cluster 1 customers

# %%
cl1_filta = update['cluster'] == 1

cl1 = update[cl1_filta]
cl1.head()
# Out:
#             invoiceno stockcode                      description  quantity  \
# customerid
# 12346.0        541431     23166   MEDIUM CERAMIC TOP STORAGE JAR     74215
# 12350.0        543037     21908    CHOCOLATE THIS WAY METAL SIGN        12
# 12350.0        543037     22412  METAL SIGN NEIGHBOURHOOD WITCH         12
# 12350.0        543037    79066K                   RETRO MOD TRAY        10
# 12350.0        543037    79191C      RETRO PLASTIC ELEPHANT TRAY        12
#
#                    invoicedate  unitprice         country    sales  \
# customerid
# 12346.0    2011-01-18 10:01:00       1.04  United Kingdom  77183.6
# 12350.0    2011-02-02 16:01:00       2.10          Norway     25.2
# 12350.0    2011-02-02 16:01:00       2.10          Norway     25.2
# 12350.0    2011-02-02 16:01:00       0.85          Norway      8.5
# 12350.0    2011-02-02 16:01:00       0.85          Norway     10.2
#
#                   invoicedate2 loyalty_level  cluster  recency  frequency  \
# ...

# %%
cl1.shape
# Out:
# (35387, 16)

# %% [markdown]
# ### 50 customers of cluster 1 and the products which they spend most on

# %%
cl1.groupby(['customerid', 'description'])['sales'].sum().nlargest(50)
# Out:
# customerid  description
# 12346.0     MEDIUM CERAMIC TOP STORAGE JAR         77183.60
# 15195.0     METAL SIGN TAKE IT OR LEAVE IT          3861.00
# 13135.0     SMALL POPCORN HOLDER                    3096.00
# 17846.0     Manual                                  2033.10
# 16986.0     JUMBO BAG RED RETROSPOT                 1790.00
# 16754.0     RED  HARMONICA IN BOX                   1484.00
# 17553.0     SOMBRERO                                1250.00
# 16698.0     PAPER CHAIN KIT EMPIRE                  1224.00
# 16692.0     VINTAGE UNION JACK BUNTING              1126.00
# 18133.0     SMALL CERAMIC TOP STORAGE JAR            931.50
# 16751.0     BAKING SET SPACEBOY DESIGN               918.00
# 16716.0     3 HOOK PHOTO SHELF ANTIQUE WHITE         901.20
# 15100.0     VICTORIAN SEWING BOX LARGE               876.00
# 15649.0     CHILLI LIGHTS                            816.00
# 16380.0     SET OF 10 LANTERNS FAIRY LIGHT STAR      750.00
# ...

# %% [markdown]
# ### 50 customers of cluster 1 and the products which they spend least on

# %%
cl1.groupby(['customerid', 'description'])['sales'].sum().nsmallest(50)
# Out:
# customerid  description
# 16198.0     PADS TO MATCH ALL CUSHIONS           0.001
# 14104.0     PORCELAIN BUDAH INCENSE HOLDER       0.100
# 15920.0     PORCELAIN BUDAH INCENSE HOLDER       0.100
# 12851.0     BLUE EGG  SPOON                      0.120
# 12743.0     RETRO PILL BOX KEY CHAIN,THE KING    0.190
# 13607.0     DECORATION SITTING BUNNY             0.190
# 15154.0     GREETING CARD, STICKY GORDON         0.190
# 15276.0     EASTER DECORATION HANGING BUNNY      0.190
# 15872.0     HAPPY BIRTHDAY CARD STRIPEY TEDDY    0.190
# 16776.0     RETRO PILL BOX , REVOLUTIONARY       0.190
# 17297.0     RETRO PILL BOX , REVOLUTIONARY       0.190
#             RETRO PILL BOX KEY CHAIN,THE KING    0.190
# 13259.0     PARTY TIME PENCIL ERASERS            0.210
# 14076.0     SLEEPING CAT ERASERS                 0.210
# 14098.0     SLEEPING CAT ERASERS                 0.210
# 15006.0     KITTY PENCIL ERASERS                 0.210
#             PARTY TIME PENCIL ERASERS            0.210
# ...

# %% [markdown]
# ### products descriptions that cluster 1 customers spend most on (largest 100)

# %%
cl1.groupby(['description'])['sales'].sum().nlargest(100)
# Out:
# description
# MEDIUM CERAMIC TOP STORAGE JAR        77520.94
# REGENCY CAKESTAND 3 TIER               7804.65
# POSTAGE                                6392.90
# JUMBO BAG RED RETROSPOT                4926.20
# WHITE HANGING HEART T-LIGHT HOLDER     4448.70
#                                         ...
# GIN + TONIC DIET METAL SIGN             953.55
# RETROSPOT HEART HOT WATER BOTTLE        946.50
# DOORMAT UNION FLAG                      937.35
# WOODEN PICTURE FRAME WHITE FINISH       935.25
# MULTI COLOUR SILVER T-LIGHT HOLDER      934.15
# Name: sales, Length: 100, dtype: float64

# %% [markdown]
# ### products descriptions that cluster 1 customers spend least on (smallest 100)

# %%
cl1.groupby(['description'])['sales'].sum().nsmallest(100)
# Out:
# description
# PADS TO MATCH ALL CUSHIONS           0.001
# HAPPY BIRTHDAY CARD STRIPEY TEDDY    0.190
# RETRO PILL BOX , REVOLUTIONARY       0.380
# RETRO PILL BOX KEY CHAIN,THE KING    0.380
# HARDMAN MUG 3 ASSORTED               0.390
#                                      ...
# BLUE CHECK BAG W HANDLE 34X20CM      2.490
# BLUE FLOWER DES PURSE                2.490
# BLUE TABLE RUN FLOWER                2.500
# EGG CUP HENRIETTA HEN CREAM          2.500
# EIGHT PIECE DINOSAUR SET             2.500
# Name: sales, Length: 100, dtype: float64

# %%
cl1['sales'].describe()
# Out:
# count    35387.000000
# mean        18.548872
# std        412.463479
# min          0.001000
# 25%          4.200000
# 50%         10.500000
# 75%         17.700000
# max      77183.600000
# Name: sales, dtype: float64

# %% [markdown]
# ### Cluster 2 customers

# %%
cl2_filta = update['cluster'] == 2

cl2 = update[cl2_filta]
cl2.head()
# Out:
#             invoiceno stockcode                      description  quantity  \
# customerid
# 12348.0        539318     84992   72 SWEETHEART FAIRY CAKE CASES        72
# 12348.0        539318     22951  60 CAKE CASES DOLLY GIRL DESIGN        72
# 12348.0        539318     84991      60 TEATIME FAIRY CAKE CASES        24
# 12348.0        539318     84991      60 TEATIME FAIRY CAKE CASES       120
# 12348.0        539318     21213      PACK OF 72 SKULL CAKE CASES        24
#
#                    invoicedate  unitprice  country  sales        invoicedate2  \
# customerid
# 12348.0    2010-12-16 19:09:00       0.55  Finland   39.6 2010-12-16 19:09:00
# 12348.0    2010-12-16 19:09:00       0.55  Finland   39.6 2010-12-16 19:09:00
# 12348.0    2010-12-16 19:09:00       0.55  Finland   13.2 2010-12-16 19:09:00
# 12348.0    2010-12-16 19:09:00       0.42  Finland   50.4 2010-12-16 19:09:00
# 12348.0    2010-12-16 19:09:00       0.55  Finland   13.2 2010-12-16 19:09:00
#
# ...

# %%
cl2.shape
# Out:
# (80845, 16)

# %% [markdown]
# ### 50 customers of cluster 2 and the products which they spend most on

# %%
cl2.groupby(['customerid', 'description'])['sales'].sum().nlargest(50)
# Out:
# customerid  description
# 15098.0     PICNIC BASKET WICKER 60 PIECES         39619.50
# 15749.0     FAIRY CAKE FLANNEL ASSORTED COLOUR     13078.80
#             WHITE HANGING HEART T-LIGHT HOLDER      9553.50
#             DOORMAT FAIRY CAKE                      8777.00
#             GIN + TONIC DIET METAL SIGN             7080.00
# 16532.0     CHILLI LIGHTS                           6374.40
# 15749.0     TEA TIME TEA TOWELS                     6045.00
# 12798.0     RABBIT NIGHT LIGHT                      5885.52
# 12980.0     SET/4 WHITE RETRO STORAGE CUBES         4962.90
# 12755.0     ROUND SNACK BOXES SET OF 4 FRUITS       3794.40
# 18087.0     EMPIRE DESIGN ROSETTE                   3202.92
# 17723.0     PARTY BUNTING                           3112.50
# 16308.0     SMALL CHINESE STYLE SCISSOR             2560.00
# 17940.0     Manual                                  1867.86
# 18073.0     ANTIQUE SILVER T-LIGHT GLASS            1785.36
# ...

# %% [markdown]
# ### 50 customers of cluster 2 and the products which they spend least on

# %%
cl2.groupby(['customerid', 'description'])['sales'].sum().nsmallest(50)
# Out:
# customerid  description
# 13952.0     PADS TO MATCH ALL CUSHIONS             0.001
# 15618.0     PADS TO MATCH ALL CUSHIONS             0.001
# 14593.0     TEATIME ROUND PENCIL SHARPENER         0.120
# 15522.0     SMALL FOLDING SCISSOR(POINTED EDGE)    0.120
# 16386.0     HOUSE SHAPE PENCIL SHARPENER           0.120
# 16898.0     ESSENTIAL BALM 3.5g TIN IN ENVELOPE    0.180
# 17537.0     ESSENTIAL BALM 3.5g TIN IN ENVELOPE    0.180
# 14529.0     SET/6 COLLAGE PAPER CUPS               0.190
#             STAR DECORATION PAINTED ZINC           0.190
# 15036.0     JAZZ HEARTS ADDRESS BOOK               0.190
# 15054.0     RETRO PILL BOX , REVOLUTIONARY         0.190
#             RETRO PILL BOX KEY CHAIN,THE KING      0.190
# 15060.0     EASTER DECORATION HANGING BUNNY        0.190
# 15483.0     RETRO PILL BOX KEY CHAIN,THE KING      0.190
# 15850.0     STAR DECORATION PAINTED ZINC           0.190
# 16898.0     HEART DECORATION RUSTIC HANGING        0.190
# ...

# %% [markdown]
# ### products descriptions that cluster 2 customers spend most on (largest 100)

# %%
cl2.groupby(['description'])['sales'].sum().nlargest(100)
# Out:
# description
# PICNIC BASKET WICKER 60 PIECES         39619.50
# WHITE HANGING HEART T-LIGHT HOLDER     24541.55
# REGENCY CAKESTAND 3 TIER               17119.60
# PARTY BUNTING                          15573.45
# POSTAGE                                15407.34
#                                          ...
# ROUND SNACK BOXES SET OF4 WOODLAND      2511.85
# DOORMAT RED RETROSPOT                   2507.85
# DOORMAT HEARTS                          2503.95
# MINI PAINT SET VINTAGE                  2493.65
# BLUE HAPPY BIRTHDAY BUNTING             2487.30
# Name: sales, Length: 100, dtype: float64

# %% [markdown]
# ### products descriptions that cluster 2 customers spend least on (largest 100)

# %%
cl2.groupby(['description'])['sales'].sum().nsmallest(100)
# Out:
# description
# PADS TO MATCH ALL CUSHIONS             0.002
# RETRO PILL BOX KEY CHAIN,THE KING      0.380
# LA PALMIERA TILE HOOK                  0.390
# HEN HOUSE WITH CHICK STANDING          0.420
# 60 GOLD AND SILVER FAIRY CAKE CASES    0.550
#                                        ...
# SCOTTIES CHILDRENS APRON               3.300
# SET/4 GARDEN ROSE DINNER CANDLE        3.300
# BLUE STRIPES SHOULDER BAG              3.320
# VINTAGE BEAD COSMETIC BAG              3.350
# LILAC GAUZE BUTTERFLY LAMPSHADE        3.360
# Name: sales, Length: 100, dtype: float64

# %%
cl2['sales'].describe()
# Out:
# count    80845.000000
# mean        18.970513
# std        151.975892
# min          0.001000
# 25%          5.040000
# 50%         12.750000
# 75%         19.500000
# max      38970.000000
# Name: sales, dtype: float64

# %% [markdown]
# ### Cluster 0 customers

# %%
cl0_filta = update['cluster'] == 0

cl0 = update[cl0_filta]
cl0.head()
# Out:
#             invoiceno stockcode                          description  \
# customerid
# 12347.0        537626     85116      BLACK CANDELABRA T-LIGHT HOLDER
# 12347.0        537626     22375    AIRLINE BAG VINTAGE JET SET BROWN
# 12347.0        537626     71477    COLOUR GLASS. STAR T-LIGHT HOLDER
# 12347.0        537626     22492              MINI PAINT SET VINTAGE
# 12347.0        537626     22771  CLEAR DRAWER KNOB ACRYLIC EDWARDIAN
#
#             quantity         invoicedate  unitprice  country  sales  \
# customerid
# 12347.0           12 2010-12-07 14:57:00       2.10  Iceland   25.2
# 12347.0            4 2010-12-07 14:57:00       4.25  Iceland   17.0
# 12347.0           12 2010-12-07 14:57:00       3.25  Iceland   39.0
# 12347.0           36 2010-12-07 14:57:00       0.65  Iceland   23.4
# 12347.0           12 2010-12-07 14:57:00       1.25  Iceland   15.0
#
#                   invoicedate2 loyalty_level  cluster  recency  frequency  \
# customerid
# ...

# %%
cl0.shape
# Out:
# (281652, 16)

# %% [markdown]
# ### 50 customers of cluster 0 and the products which they spend most on

# %%
cl0.groupby(['customerid', 'description'])['sales'].sum().nlargest(50)
# Out:
# customerid  description
# 16446.0     PAPER CRAFT , LITTLE BIRDIE            168469.60
# 18102.0     VINTAGE UNION JACK MEMOBOARD            16592.08
# 16210.0     BLACK RECORD COVER FRAME                16027.92
# 18102.0     WOOD BLACK BOARD ANT WHITE FINISH       15351.00
#             CREAM HEART CARD HOLDER                 14089.90
# 15061.0     REGENCY CAKESTAND 3 TIER                14081.70
# 17450.0     HEART OF WICKER LARGE                   13459.64
#             WHITE HANGING HEART T-LIGHT HOLDER      13253.84
# 12744.0     Manual                                  12158.90
# 14096.0     DOTCOM POSTAGE                          11906.36
# 17450.0     SET OF TEA COFFEE SUGAR TINS PANTRY     10566.73
#             HEART OF WICKER SMALL                   10201.98
# 14646.0     RABBIT NIGHT LIGHT                       9568.48
# 18102.0     BLACK HEART CARD HOLDER                  9482.40
# 16333.0     RED  HARMONICA IN BOX                    8607.20
# ...

# %% [markdown]
# ### 50 customers of cluster 0 and the products which they spend least on

# %%
cl0.groupby(['customerid', 'description'])['sales'].sum().nsmallest(50)
# Out:
# customerid  description
# 15858.0     PORCELAIN BUDAH INCENSE HOLDER         0.10
# 14159.0     SMALL FOLDING SCISSOR(POINTED EDGE)    0.12
# 14796.0     TOOTHPASTE TUBE PEN                    0.12
# 14963.0     DISCO BALL CHRISTMAS DECORATION        0.12
#             ICON PLACEMAT POP ART ELVIS            0.12
# 15436.0     BLUE PUDDING SPOON                     0.12
# 16332.0     TEATIME ROUND PENCIL SHARPENER         0.12
# 16442.0     TOOTHPASTE TUBE PEN                    0.12
# 16923.0     RED  EGG  SPOON                        0.12
# 16931.0     ICON PLACEMAT POP ART ELVIS            0.12
# 17315.0     HANGING WOOD AND FELT FLOWER           0.12
# 17571.0     TEATIME ROUND PENCIL SHARPENER         0.12
# 17920.0     DISCO BALL CHRISTMAS DECORATION        0.12
# 18116.0     WINE BOTTLE DRESSING LT.BLUE           0.12
# 14404.0     PAPER POCKET TRAVELING FAN             0.14
# 15426.0     PAPER POCKET TRAVELING FAN             0.14
# ...

# %% [markdown]
# ### products descriptions that cluster 2 customers spend most on (largest 100)

# %%
cl0.groupby(['description'])['sales'].sum().nlargest(100)
# Out:
# description
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# REGENCY CAKESTAND 3 TIER              117668.70
# WHITE HANGING HEART T-LIGHT HOLDER     71457.90
# JUMBO BAG RED RETROSPOT                69834.30
# POSTAGE                                56003.72
#                                         ...
# HAND WARMER OWL DESIGN                 12202.33
# LUNCH BAG SUKI DESIGN                  12188.80
# WOOD 2 DRAWER CABINET WHITE FINISH     12009.22
# SET OF 4 PANTRY JELLY MOULDS           11962.60
# DOTCOM POSTAGE                         11906.36
# Name: sales, Length: 100, dtype: float64

# %% [markdown]
# ### products descriptions that cluster 2 customers spend least on (largest 100)

# %%
cl0.groupby(['description'])['sales'].sum().nsmallest(100)
# Out:
# description
# PINK CRYSTAL SKULL PHONE CHARM    0.19
# LETTER "F" BLING KEY RING         0.29
# HEN HOUSE W CHICK IN NEST         0.42
# HEN HOUSE WITH CHICK STANDING     0.42
# LADLE LOVE HEART PINK             0.42
#                                   ...
# CLEAR STATIONERY BOX SET          5.10
# ENVELOPE 50 ROMANTIC IMAGES       5.10
# IVORY SHELL HEART EARRINGS        5.10
# POLYESTER FILLER PAD 60x40cm      5.10
# RASTA IN BATH W SPLIFF ASHTRAY    5.10
# Name: sales, Length: 100, dtype: float64

# %%
cl0.sales.describe()
# Out:
# count    281652.000000
# mean         23.864016
# std         327.009163
# min           0.060000
# 25%           4.400000
# 50%          11.580000
# 75%          19.800000
# max      168469.600000
# Name: sales, dtype: float64

# %% [markdown]
# <div class='alert alert-info'>
#     <h3>Significance of the Segmentation Analysis</h3>
#     <p>The marketing department can use the insights gained from the clusters to target certain marketing strategies like ads and promotions at the clusters in order to boost sales. Knowing the descriptions of customers in the different clusters, personalization of purchases goods can be a way of improving customer satisfaction. These and many more can be done with the analysis to improve sales and customer satisfaction.
# </div>
