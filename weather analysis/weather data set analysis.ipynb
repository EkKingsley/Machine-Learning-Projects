# %% [markdown]
# # Weather data analysis
#
# weather.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('weather_data.csv', parse_dates=['Date/Time'])
df.head()
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#             date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    visibility_km  press_kpa               weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.count()
# Out:
# date/time           8784
# temp_c              8784
# dew point temp_c    8784
# rel hum_%           8784
# wind speed_km/h     8784
# visibility_km       8784
# press_kpa           8784
# weather             8784
# dtype: int64

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.describe()
# Out:
#             temp_c  dew point temp_c    rel hum_%  wind speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        visibility_km    press_kpa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df.describe(include=['object'])
# Out:
#              weather
# count           8784
# unique            50
# top     Mainly Clear
# freq            2106

# %%
df.weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
df.columns
# Out:
# Index(['date/time', 'temp_c', 'dew point temp_c', 'rel hum_%',
#        'wind speed_km/h', 'visibility_km', 'press_kpa', 'weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# date/time           datetime64[ns]
# temp_c                     float64
# dew point temp_c           float64
# rel hum_%                    int64
# wind speed_km/h              int64
# visibility_km              float64
# press_kpa                  float64
# weather                     object
# dtype: object

# %%
df.weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.weather.nunique()
# Out:
# 50

# %%
df.nunique()
# Out:
# date/time           8784
# temp_c               533
# dew point temp_c     489
# rel hum_%             83
# wind speed_km/h       34
# visibility_km         24
# press_kpa            518
# weather               50
# dtype: int64

# %%
df.count()
# Out:
# date/time           8784
# temp_c              8784
# dew point temp_c    8784
# rel hum_%           8784
# wind speed_km/h     8784
# visibility_km       8784
# press_kpa           8784
# weather             8784
# dtype: int64

# %%
df.value_counts()
# Out:
# date/time            temp_c  dew point temp_c  rel hum_%  wind speed_km/h  visibility_km  press_kpa  weather
# 2012-01-01 00:00:00  -1.8    -3.9              86         4                8.0            101.24     Fog             1
# 2012-09-01 03:00:00   17.7    12.8             73         11               25.0           101.13     Mainly Clear    1
# 2012-08-31 21:00:00   21.6    19.0             85         11               25.0           100.65     Mainly Clear    1
# 2012-08-31 22:00:00   21.7    16.9             74         20               25.0           100.78     Mainly Clear    1
# 2012-08-31 23:00:00   20.8    12.9             61         11               25.0           100.84     Clear           1
#                                                                                                                     ..
# 2012-05-01 17:00:00   10.0    8.4              90         7                4.0            101.21     Rain,Fog        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date/time         8784 non-null   datetime64[ns]
#  1   temp_c            8784 non-null   float64
#  2   dew point temp_c  8784 non-null   float64
#  3   rel hum_%         8784 non-null   int64
#  4   wind speed_km/h   8784 non-null   int64
#  5   visibility_km     8784 non-null   float64
#  6   press_kpa         8784 non-null   float64
#  7   weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %% [markdown]
# **All the unique 'wind speed' values in the data**

# %%
df['wind speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df['wind speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# **Find the number of times when the 'weather is exactly clear'**

# %%
df.weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# filtering for weather that is Mainly Clear and Clear

filta_mainlyClear_clear = (df['weather'] == 'Mainly Clear') | (df['weather'] == 'Clear')
df[filta_mainlyClear_clear].shape[0]
# Out:
# 3432

# %%
df[filta_mainlyClear_clear].head()
# Out:
#              date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 36 2012-01-02 12:00:00     1.7              -6.2         56               48
# 60 2012-01-03 12:00:00   -14.9             -22.6         52               20
# 61 2012-01-03 13:00:00   -15.1             -22.4         54               22
# 62 2012-01-03 14:00:00   -14.9             -22.9         50               22
# 63 2012-01-03 15:00:00   -14.8             -22.2         53               19
#
#     visibility_km  press_kpa       weather
# 36           24.1      99.21  Mainly Clear
# 60           24.1     101.34  Mainly Clear
# 61           24.1     101.34  Mainly Clear
# 62           24.1     101.38  Mainly Clear
# 63           24.1     101.44  Mainly Clear

# %%
# filtering for weather that is Mainly Clear

filta_mainlyClear = df['weather'] == 'Mainly Clear'
df[filta_mainlyClear].shape[0]
# Out:
# 2106

# %%
df[filta_mainlyClear].head()
# Out:
#              date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 36 2012-01-02 12:00:00     1.7              -6.2         56               48
# 60 2012-01-03 12:00:00   -14.9             -22.6         52               20
# 61 2012-01-03 13:00:00   -15.1             -22.4         54               22
# 62 2012-01-03 14:00:00   -14.9             -22.9         50               22
# 63 2012-01-03 15:00:00   -14.8             -22.2         53               19
#
#     visibility_km  press_kpa       weather
# 36           24.1      99.21  Mainly Clear
# 60           24.1     101.34  Mainly Clear
# 61           24.1     101.34  Mainly Clear
# 62           24.1     101.38  Mainly Clear
# 63           24.1     101.44  Mainly Clear

# %%
# filtering for weather that is Clear

filta_clear = df['weather'] == 'Clear'
df[filta_clear].shape[0]
# Out:
# 1326

# %%
df[filta_clear].head()
# Out:
#               date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 67  2012-01-03 19:00:00   -16.9             -24.8         50               24
# 114 2012-01-05 18:00:00    -7.1             -14.4         56               11
# 115 2012-01-05 19:00:00    -9.2             -15.4         61                7
# 116 2012-01-05 20:00:00    -9.8             -15.7         62                9
# 117 2012-01-05 21:00:00    -9.0             -14.8         63               13
#
#      visibility_km  press_kpa weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
df.groupby('weather').get_group('Clear').head()
# Out:
#               date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 67  2012-01-03 19:00:00   -16.9             -24.8         50               24
# 114 2012-01-05 18:00:00    -7.1             -14.4         56               11
# 115 2012-01-05 19:00:00    -9.2             -15.4         61                7
# 116 2012-01-05 20:00:00    -9.8             -15.7         62                9
# 117 2012-01-05 21:00:00    -9.0             -14.8         63               13
#
#      visibility_km  press_kpa weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %% [markdown]
# **Find the number of times when the 'Wind Speed was exactly 4 km/h'**

# %%
df['wind speed_km/h'].dtype
# Out:
# dtype('int64')

# %%
df[df['wind speed_km/h'] == 4].shape[0]
# Out:
# 474

# %%
df[df['wind speed_km/h'] == 4].head()
# Out:
#               date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 0   2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1   2012-01-01 01:00:00    -1.8              -3.7         87                4
# 96  2012-01-05 00:00:00    -8.8             -11.7         79                4
# 101 2012-01-05 05:00:00    -7.0              -9.5         82                4
# 146 2012-01-07 02:00:00    -8.1             -11.1         79                4
#
#      visibility_km  press_kpa weather
# 0              8.0     101.24     Fog
# 1              8.0     101.24     Fog
# 96             9.7     100.32    Snow
# 101            4.0     100.19    Snow
# 146           19.3     100.15  Cloudy

# %% [markdown]
# **Find out all the Null values in the data**

# %%
df.isnull().sum()
# Out:
# date/time           0
# temp_c              0
# dew point temp_c    0
# rel hum_%           0
# wind speed_km/h     0
# visibility_km       0
# press_kpa           0
# weather             0
# dtype: int64

# %% [markdown]
# **Rename the column name 'Weather' of the dataframe to 'Weather Condition'**

# %%
df.rename(columns={'weather':'weather condition'}, inplace=True)
df.head()
# Out:
#             date/time  temp_c  dew point temp_c  rel hum_%  wind speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
# 2 2012-01-01 02:00:00    -1.8              -3.4         89                7
# 3 2012-01-01 03:00:00    -1.5              -3.2         88                6
# 4 2012-01-01 04:00:00    -1.5              -3.3         88                7
#
#    visibility_km  press_kpa     weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# **What is the mean 'visibility'**

# %%
df.columns
# Out:
# Index(['date/time', 'temp_c', 'dew point temp_c', 'rel hum_%',
#        'wind speed_km/h', 'visibility_km', 'press_kpa', 'weather condition'],
#       dtype='object')

# %%
df['visibility_km'].dtypes
# Out:
# dtype('float64')

# %%
df.visibility_km.mean().round(2)
# Out:
# 27.66

# %% [markdown]
# **what is the Standard deviation of 'Pressure' in this data?**

# %%
df['press_kpa'].std().round(2)
# Out:
# 0.84

# %% [markdown]
# **What is the variance of 'Relative Humidity' in this data?**

# %%
df['rel hum_%'].var().round(2)
# Out:
# 286.25

# %% [markdown]
# **Find all instances when 'Snow' was recorded**

# %%
df[df['weather condition'] == 'Snow']
# Out:
#                date/time  temp_c  dew point temp_c  rel hum_%  \
# 55   2012-01-03 07:00:00   -14.0             -19.5         63
# 84   2012-01-04 12:00:00   -13.7             -21.7         51
# 86   2012-01-04 14:00:00   -11.3             -19.0         53
# 87   2012-01-04 15:00:00   -10.2             -16.3         61
# 88   2012-01-04 16:00:00    -9.4             -15.5         61
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       wind speed_km/h  visibility_km  press_kpa weather condition
# 55                 19           25.0     100.95              Snow
# 84                 11           24.1     101.25              Snow
# ...

# %%
# contains snow
df[df['weather condition'].str.contains('Snow')]
# Out:
#                date/time  temp_c  dew point temp_c  rel hum_%  \
# 41   2012-01-02 17:00:00    -2.1              -9.5         57
# 44   2012-01-02 20:00:00    -5.6             -13.4         54
# 45   2012-01-02 21:00:00    -5.8             -12.8         58
# 47   2012-01-02 23:00:00    -7.4             -14.1         59
# 48   2012-01-03 00:00:00    -9.0             -16.0         57
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       wind speed_km/h  visibility_km  press_kpa weather condition
# 41                 22           25.0      99.66      Snow Showers
# 44                 24           25.0     100.07      Snow Showers
# ...

# %% [markdown]
# **find all the instances when 'Wind Speed' is above 24 and 'Visibility is 25'**

# %%
fil = (df['wind speed_km/h'] > 25) & (df['visibility_km'] == 25)

# %%
df[fil]
# Out:
#                date/time  temp_c  dew point temp_c  rel hum_%  \
# 23   2012-01-01 23:00:00     5.3               2.0         79
# 24   2012-01-02 00:00:00     5.2               1.5         77
# 25   2012-01-02 01:00:00     4.6               0.0         72
# 26   2012-01-02 02:00:00     3.9              -0.9         71
# 27   2012-01-02 03:00:00     3.7              -1.5         69
# ...                  ...     ...               ...        ...
# 8705 2012-12-28 17:00:00    -8.6             -12.0         76
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8759 2012-12-30 23:00:00   -12.1             -15.1         78
# 8760 2012-12-31 00:00:00   -11.1             -14.4         77
#
#       wind speed_km/h  visibility_km  press_kpa weather condition
# 23                 30           25.0      99.31            Cloudy
# 24                 35           25.0      99.26      Rain Showers
# ...

# %% [markdown]
# **What is the mean value of each column against each 'Weather condition'**

# %%
df.groupby('weather condition')[['temp_c', 'dew point temp_c', 'rel hum_%', 'wind speed_km/h', 'visibility_km', 'press_kpa']].mean().round(2)
# Out:
#                                          temp_c  dew point temp_c  rel hum_%  \
# weather condition
# Clear                                      6.83              0.09      64.50
# Cloudy                                     7.97              2.38      69.59
# Drizzle                                    7.35              5.50      88.24
# Drizzle,Fog                                8.07              7.03      93.28
# Drizzle,Ice Pellets,Fog                    0.40             -0.70      92.00
# Drizzle,Snow                               1.05              0.15      93.50
# Drizzle,Snow,Fog                           0.69              0.12      95.87
# Fog                                        4.30              3.16      92.29
# Freezing Drizzle                          -5.66             -8.00      83.57
# Freezing Drizzle,Fog                      -2.53             -4.18      88.50
# Freezing Drizzle,Haze                     -5.43             -8.00      82.00
# ...

# %%
df.groupby('weather condition').mean().round(2)
# Out:
#                                          temp_c  dew point temp_c  rel hum_%  \
# weather condition
# Clear                                      6.83              0.09      64.50
# Cloudy                                     7.97              2.38      69.59
# Drizzle                                    7.35              5.50      88.24
# Drizzle,Fog                                8.07              7.03      93.28
# Drizzle,Ice Pellets,Fog                    0.40             -0.70      92.00
# Drizzle,Snow                               1.05              0.15      93.50
# Drizzle,Snow,Fog                           0.69              0.12      95.87
# Fog                                        4.30              3.16      92.29
# Freezing Drizzle                          -5.66             -8.00      83.57
# Freezing Drizzle,Fog                      -2.53             -4.18      88.50
# Freezing Drizzle,Haze                     -5.43             -8.00      82.00
# ...

# %% [markdown]
# **What is the minimum & maximum value of each column against each 'Weather Condition'?**

# %%
df.groupby('weather condition').agg(['min', 'max'])
# Out:
#                                                   date/time  \
#                                                         min
# weather condition
# Clear                                   2012-01-03 19:00:00
# Cloudy                                  2012-01-01 17:00:00
# Drizzle                                 2012-01-23 21:00:00
# Drizzle,Fog                             2012-01-23 20:00:00
# Drizzle,Ice Pellets,Fog                 2012-12-17 09:00:00
# Drizzle,Snow                            2012-12-17 15:00:00
# Drizzle,Snow,Fog                        2012-12-18 21:00:00
# Fog                                     2012-01-01 00:00:00
# Freezing Drizzle                        2012-01-07 11:00:00
# Freezing Drizzle,Fog                    2012-01-01 02:00:00
# Freezing Drizzle,Haze                   2012-02-01 11:00:00
# Freezing Drizzle,Snow                   2012-01-13 03:00:00
# Freezing Fog                            2012-01-22 06:00:00
# ...

# %% [markdown]
# **Show all the Records where weather condition is Fog**

# %%
df[df['weather condition'] == 'Fog']
# Out:
#                date/time  temp_c  dew point temp_c  rel hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8717 2012-12-29 05:00:00   -14.8             -15.9         91
# 8718 2012-12-29 06:00:00   -13.8             -15.3         88
# 8719 2012-12-29 07:00:00   -14.8             -16.4         88
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
#
#       wind speed_km/h  visibility_km  press_kpa weather condition
# 0                   4            8.0     101.24               Fog
# 1                   4            8.0     101.24               Fog
# ...

# %% [markdown]
# **find all instances when 'weather is clear' or visibility is above 40'**

# %%
filtar = (df['weather condition'] == 'Clear') | (df['visibility_km'] > 40)

df[filtar]
# Out:
#                date/time  temp_c  dew point temp_c  rel hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       wind speed_km/h  visibility_km  press_kpa weather condition
# 67                 24           25.0     101.74             Clear
# 106                17           48.3     100.45      Mainly Clear
# ...

# %% [markdown]
# **find all instances when:'weather is Clear' and 'Relative Humidity is greater than 50'**
#
# or
#
# **'Visibility is above 40'**

# %%
df.columns
# Out:
# Index(['date/time', 'temp_c', 'dew point temp_c', 'rel hum_%',
#        'wind speed_km/h', 'visibility_km', 'press_kpa', 'weather condition'],
#       dtype='object')

# %%
filtaa = ((df['weather condition'] == 'Clear') & (df['rel hum_%'] > 50)) | (df['visibility_km'] > 40)

# %%
df[filtaa]
# Out:
#                date/time  temp_c  dew point temp_c  rel hum_%  \
# 106  2012-01-05 10:00:00    -6.0             -10.0         73
# 107  2012-01-05 11:00:00    -5.6             -10.2         70
# 108  2012-01-05 12:00:00    -4.7              -9.6         69
# 109  2012-01-05 13:00:00    -4.4              -9.7         66
# 110  2012-01-05 14:00:00    -5.1             -10.7         65
# ...                  ...     ...               ...        ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2         73
# 8750 2012-12-30 14:00:00   -11.8             -16.1         70
# 8751 2012-12-30 15:00:00   -11.3             -15.6         70
# 8752 2012-12-30 16:00:00   -11.4             -15.5         72
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       wind speed_km/h  visibility_km  press_kpa weather condition
# 106                17           48.3     100.45      Mainly Clear
# 107                22           48.3     100.41      Mainly Clear
# ...
